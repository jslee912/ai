# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:90%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:14pt;}
div.text_cell_render.rendered_html{font-size:14pt;}
div.text_cell_render ul li, code{font-size:22pt; line-height:14px;}
div.output {font-size:14pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:14pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:14pt;padding:5px;}
table.dataframe{font-size:14px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:90%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:14pt;}
# div.text_cell_render.rendered_html{font-size:14pt;}
# div.text_cell_render ul li, code{font-size:22pt; line-height:14px;}
# div.output {font-size:14pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:14pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:14pt;padding:5px;}
# table.dataframe{font-size:14px;}
# </style>

# %% [markdown]
# # ※ Quiz : 경주여행과 전주여행에 대해 최빈단어 시각화와 유사도 분석
# - (1) naver open API를 활용하여 네이버지식인 "전주여행","경주여행"을 각각 500건씩 검색 백업(naver.csv)
#     * replace(), re.sum()이용 - 웹크롤링, 정규표현식
#     * 백업 파일 결과 : query,no,title,link,description,total_text(title+' '+description)
# - (2) 품사태깅 백업(naver_pos.csv)
#     * query, no, token, pos
# - (3) 명사만 추출 백업(naver_pos_nouns.csv)
#     * query, token, pos
# - (4) 빈도분석 백업(naver_pos_nouns_count.csv)
#     * token, 경주빈도, 전주빈도, 빈도합
# - (5) 빈도 시각화(워드클라우드, Text.plot)
#     * 워드클라우드 이미지 저장
# - (6) 단어간 유사도 분석(Word2Vec, 연관분석)
#
# # 1. naver open API를 활용하여 검색어에 대해 500건 추출
# - query,no,title,link,description,total_text(title+' '+description)

# %%
# .env 가져오기(방법1)-추천(주피터노트북에서)
from dotenv import load_dotenv
import os
load_dotenv()
# print(os.getenv('CLIENT_ID'))
# print(os.getenv('CLIENT_SECRET'))
# Out:
# True

# %%
# .env 가져오기(방법2)-vsCode에서 추천
from decouple import config
# print(os.getenv('CLIENT_ID'))
# print(os.getenv('CLIENT_SECRET'))

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
encText = urllib.parse.quote("경주 여행")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')[:200])
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 02 Dec 2025 16:21:07 +0900",
# 	"total":1003249,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"내 마음대로 기록하는 <b>경주여행<\/b> 2박3일",
# 			"link":"https:\/\/blog.naver.com\/hello

# %%
# 방법1
import requests
import pandas as pd
import json  # response 텍스트를 json스타일의 딕셔너리로
import re    # 정규표현식
from html import unescape  # description에 &lt;등의 특수문자를 <(문자)로 변경

client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
query = '경주 여행'
start = 1
headers = {
    'X-Naver-Client-Id':client_id,
    'X-Naver-Client-Secret':client_secret
}
# url = f'https://openapi.naver.com/v1/search/kin?query={query}&display=100&start={start}'
# response = requests.get(url, headers=headers)
url = 'https://openapi.naver.com/v1/search/kin'
params = {'query':query, 'display':100, 'start':start}
response = requests.get(url, params=params, headers=headers)
# print(response.text[:500])
# items = json.loads(response.text)['items']
items = response.json()['items']
print(len(items))
# Out:
# 100

# %%
# title, link, description 추출(b태그삭제, 특수문자조정,(&gt,: -> >), 정규표현식을 이용한 한글추출)
item  = items[97]
title = item.get('title').replace('<b>', '').replace('</b>', '')
link  = item['link']
description = item.get('description').replace('<b>', '').replace('</b>', '')
# html 특수 문자 처리
description = unescape(description)
# 정규표현식 : 알파벳, 숫자, 한글만 남기고 나머지는 제거
description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ',description)
description = re.sub('\s+',' ', description)
print(title, link, description)
# Out:
# 경주 여행지 추천 https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=261370795&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8  2 부산을 벗어난 경주 여행지 알려주세요 3 당일치기로 경주 여행코스 밑에 자세하게 권역별로 여행코스를 소개했습니다 경주여행이 처음이라면 대릉원 첨성대 참고로 쭈니아빠 블로그를 방문하시면 경주여행

# %%
def get_search_element_return(query, start):
    headers = {
        'X-Naver-Client-Id':client_id,
        'X-Naver-Client-Secret':client_secret
    }
    # url = f'https://openapi.naver.com/v1/search/kin?query={query}&display=100&start={start}'
    # response = requests.get(url, headers=headers)
    url = 'https://openapi.naver.com/v1/search/kin'
    params = {'query':query, 'display':100, 'start':start}
    response = requests.get(url, params=params, headers=headers)
    # print(response.text[:500])
    # items = json.loads(response.text)['items']
    items = response.json()['items']
    result = [] # 검색한 정보를 append할 리스트
    for i, item in enumerate(items):
        title = item.get('title').replace('<b>', ' ').replace('</b>', ' ')
        link  = item.get('link')
        description = item.get('description').replace('<b>', ' ').replace('</b>', ' ')
        # html 특수 문자 처리
        description = unescape(description)
        # 정규표현식 : 영문자, 숫자, 한글을 제외한 문자 제거
        description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ',description)
        description = re.sub('\s+',' ', description) # 공백은 하나만두고
        result.append({       # 딕셔너리 리스트
            'query':query,
            'no':(start-1)*100 + i+1,
            'title':title,
            'link':link,
            'description':description,
            'total_text': title + ' ' + description
        })
    return result

# %%
get_search_element_return("전주 여행", 2)
# Out:
# [{'query': '전주 여행',
#   'no': 101,
#   'title': 'KTX로 떠나는  전주 여행 , 주요 관광지 도보 이동... ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=489674913&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 여행 계획 중이시군요 전주역에서 한옥마을까지는 사실 도보로는 좀 멀어요 약 3km 정도 되고 40분 정도 걸립니다 그래서 대부분 택시나 버스를 이용하시는데 택시는 10분 정도면 도착하고 요금도 7 8천원 정도로 부담 없어요 ',
#   'total_text': 'KTX로 떠나는  전주 여행 , 주요 관광지 도보 이동...   전주 여행 계획 중이시군요 전주역에서 한옥마을까지는 사실 도보로는 좀 멀어요 약 3km 정도 되고 40분 정도 걸립니다 그래서 대부분 택시나 버스를 이용하시는데 택시는 10분 정도면 도착하고 요금도 7 8천원 정도로 부담 없어요 '},
#  {'query': '전주 여행',
#   'no': 102,
#   'title': '아이와  전주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=486608876&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '7월 중순에 초3아이와 같이 당일치기로 전주여행 다녀올려는데 어딜가야할까요 전주는 처음이라 어디가야할지 식당은 어디가 맛있을지 모르겠어요 안녕하세요 7월 중순에 초3 아이와 전주 당일치기 여행이라면 아이도 즐겁고 부모님도 ',
#   'total_text': '아이와  전주여행  7월 중순에 초3아이와 같이 당일치기로 전주여행 다녀올려는데 어딜가야할까요 전주는 처음이라 어디가야할지 식당은 어디가 맛있을지 모르겠어요 안녕하세요 7월 중순에 초3 아이와 전주 당일치기 여행이라면 아이도 즐겁고 부모님도 '},
#  {'query': '전주 여행',
#   'no': 103,
#   'title': ' 전주  커플 여행  1박 2일 코스에 포함된 문화 체험 활동은... ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90105&docId=488889750&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 여행 중 커플들이 함께 즐길 수 있는 문화 체험 활동에는 어떤 것들이 포함되어 있는지 알고 싶습니다 한복 대여 전통 공예 체험 등 특별한 경험이 가능한 프로그램을 추천해주세요 전주는 한옥마을 중심의 전통문화와 현대 ',
#   'total_text': ' 전주  커플 여행  1박 2일 코스에 포함된 문화 체험 활동은...   전주 여행 중 커플들이 함께 즐길 수 있는 문화 체험 활동에는 어떤 것들이 포함되어 있는지 알고 싶습니다 한복 대여 전통 공예 체험 등 특별한 경험이 가능한 프로그램을 추천해주세요 전주는 한옥마을 중심의 전통문화와 현대 '},
#  {'query': '전주 여행',
#   'no': 104,
#   'title': '중2 여학생 친구와  전주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=480969931&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 중 2 15살 여학생입니다 친한친구와 둘이서 전주 여행 을 가기로 했는데 어디로 가야할지를 몰라서 너무 막막합니다 저희 둘다 일본 애니를 너무 좋아하는데전주에 오타쿠들이 갈만할 곳 있을까요 제발 알려주세요 ',
#   'total_text': '중2 여학생 친구와  전주여행  안녕하세요 중 2 15살 여학생입니다 친한친구와 둘이서 전주 여행 을 가기로 했는데 어디로 가야할지를 몰라서 너무 막막합니다 저희 둘다 일본 애니를 너무 좋아하는데전주에 오타쿠들이 갈만할 곳 있을까요 제발 알려주세요 '},
#  {'query': '전주 여행',
#   'no': 105,
#   'title': ' 전주여행 갈려고하는데요!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=472294467&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 을 갈려고하는데요 아는사람과 갈려고하는데 호텔은 좋은가격에 정했고 음 2박3일여행인데 얼마정도갖고가면좋을까요 그리고 맛집같은거 카페같은거 추천해주세요 안녕하세요 전주 여행 계획 중이시네요 한옥마을 근처 ',
#   'total_text': ' 전주여행 갈려고하는데요!  전주여행 을 갈려고하는데요 아는사람과 갈려고하는데 호텔은 좋은가격에 정했고 음 2박3일여행인데 얼마정도갖고가면좋을까요 그리고 맛집같은거 카페같은거 추천해주세요 안녕하세요 전주 여행 계획 중이시네요 한옥마을 근처 '},
#  {'query': '전주 여행',
#   'no': 106,
#   'title': ' 전주  1박 2일  여행 에서 꼭 가봐야 할 맛집 추천좀요!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=486437049&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 여행 을 계획 중인데 1박 2일 동안 효율적으로 즐길 수 있는 맛집과 포토 스팟을 알고 싶습니다 특히 오목대와 같은 숨겨진 명소와 현지인들이 자주 가는 맛집 정보도 궁금해요 여행 일정에 포함할 수 있도록 다양한 추천 ',
#   'total_text': ' 전주  1박 2일  여행 에서 꼭 가봐야 할 맛집 추천좀요!  전주 여행 을 계획 중인데 1박 2일 동안 효율적으로 즐길 수 있는 맛집과 포토 스팟을 알고 싶습니다 특히 오목대와 같은 숨겨진 명소와 현지인들이 자주 가는 맛집 정보도 궁금해요 여행 일정에 포함할 수 있도록 다양한 추천 '},
#  {'query': '전주 여행',
#   'no': 107,
#   'title': ' 전주 여행  중 꼭 맛봐야 할 지역 특색 음식은 무엇인가요?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40702&docId=489981062&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 에 가면 꼭 먹어봐야 할 음식들이 많다고 들었습니다 비빔밥 외에도 현지인들이 자주 찾는 맛집이나 특별한 짬뽕과 짜장만 팜 한옥마을 인근으로 추천해드릴만한곳은 이정도네요 그럼 즐거운 여행 되시기를 ',
#   'total_text': ' 전주 여행  중 꼭 맛봐야 할 지역 특색 음식은 무엇인가요?  전주 에 가면 꼭 먹어봐야 할 음식들이 많다고 들었습니다 비빔밥 외에도 현지인들이 자주 찾는 맛집이나 특별한 짬뽕과 짜장만 팜 한옥마을 인근으로 추천해드릴만한곳은 이정도네요 그럼 즐거운 여행 되시기를 '},
#  {'query': '전주 여행',
#   'no': 108,
#   'title': '부모닝 모시고  전주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=480179536&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '부모님 모시고 전주여행 가려는데 명소 식당 추천부탁드립니다 전주는 한옥마을로 유명한 완산구가 있으며 덕진구 또한 멋진 추억을 가진 장소가 많이 ',
#   'total_text': '부모닝 모시고  전주여행  부모님 모시고 전주여행 가려는데 명소 식당 추천부탁드립니다 전주는 한옥마을로 유명한 완산구가 있으며 덕진구 또한 멋진 추억을 가진 장소가 많이 '},
#  {'query': '전주 여행',
#   'no': 109,
#   'title': ' 전주  맛집 및 명소 추천해주세요!_내일  여행 갑니다',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=487630461&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 감사합니다 안녕하세요 전주 여행 일정으로 고민 중이신 질문자님 1박 2일로 떠나는 전주 첫 여행 설레기도 하고 막상 어디부터 갈지 고민도 많으시죠 저도 여름에 전주 다녀온 적 있어서 짧지만 알차게 즐길 수 있는 코스 위주로 ',
#   'total_text': ' 전주  맛집 및 명소 추천해주세요!_내일  여행 갑니다  감사합니다 안녕하세요 전주 여행 일정으로 고민 중이신 질문자님 1박 2일로 떠나는 전주 첫 여행 설레기도 하고 막상 어디부터 갈지 고민도 많으시죠 저도 여름에 전주 다녀온 적 있어서 짧지만 알차게 즐길 수 있는 코스 위주로 '},
#  {'query': '전주 여행',
#   'no': 110,
#   'title': ' 전주 여행 코스 추천이요~!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=442151278&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '영화제 기간 일정으로 2박3일 전주여행 좀 가볼까 해서요 여행코스 추천 좀 해주세요 어차피 주목적은 전주국제영화제니까 많은 곳을 둘러보지는 못할거에요 그냥 전주하면 꼭 가볼만한 곳 알짜배기만 추천해주세욜 전주 ',
#   'total_text': ' 전주 여행 코스 추천이요~! 영화제 기간 일정으로 2박3일 전주여행 좀 가볼까 해서요 여행코스 추천 좀 해주세요 어차피 주목적은 전주국제영화제니까 많은 곳을 둘러보지는 못할거에요 그냥 전주하면 꼭 가볼만한 곳 알짜배기만 추천해주세욜 전주 '},
#  {'query': '전주 여행',
#   'no': 111,
#   'title': ' 전주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=480354904&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 주세요 전주 는 한옥마을로 유명한 완산구가 있으며 덕진구 또한 멋진 추억을 가진 장소가 많이 있습니다 완산구 덕진구에 대해서 여행 지를 ',
#   'total_text': ' 전주 여행   주세요 전주 는 한옥마을로 유명한 완산구가 있으며 덕진구 또한 멋진 추억을 가진 장소가 많이 있습니다 완산구 덕진구에 대해서 여행 지를 '},
#  {'query': '전주 여행',
#   'no': 112,
#   'title': ' 전주  맛집 및 명소 추천해주세요!_내일  여행 갑니다',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=487633672&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 많은 추천 바랍니다 여러 분이 답 달아주시면 더 좋습니다 감사합니다 안녕하세요 전주 여행 계획 중이신 질문자님 한옥마을 중심으로 일정을 잡으신 거 보니 감성 여행 기대하고 계신 것 같아요 저도 전주 1박 2일 다녀온 ',
#   'total_text': ' 전주  맛집 및 명소 추천해주세요!_내일  여행 갑니다  많은 추천 바랍니다 여러 분이 답 달아주시면 더 좋습니다 감사합니다 안녕하세요 전주 여행 계획 중이신 질문자님 한옥마을 중심으로 일정을 잡으신 거 보니 감성 여행 기대하고 계신 것 같아요 저도 전주 1박 2일 다녀온 '},
#  {'query': '전주 여행',
#   'no': 113,
#   'title': '2박3일  전주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=472470179&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '부모님과 전주여행 가려고하는데 정보가 하나도 없어서요 숙소는 어디가좋은지 관광지는 어디가있는지 추천부탁드려요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 ',
#   'total_text': '2박3일  전주여행  부모님과 전주여행 가려고하는데 정보가 하나도 없어서요 숙소는 어디가좋은지 관광지는 어디가있는지 추천부탁드려요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 '},
#  {'query': '전주 여행',
#   'no': 114,
#   'title': ' 전주여행  대중교통이랑 렌트카중 어떤게 좋을까요?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=477694429&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 때 움직이기 차가 편할지 대중교통이 편할지 알려주세요 교통 상황이 어떤지 궁금합니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 ',
#   'total_text': ' 전주여행  대중교통이랑 렌트카중 어떤게 좋을까요?  전주여행 때 움직이기 차가 편할지 대중교통이 편할지 알려주세요 교통 상황이 어떤지 궁금합니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 '},
#  {'query': '전주 여행',
#   'no': 115,
#   'title': ' 전주  1박 2일  여행  관련 질문~',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=483471047&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 보내세요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 ',
#   'total_text': ' 전주  1박 2일  여행  관련 질문~  보내세요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 '},
#  {'query': '전주 여행',
#   'no': 116,
#   'title': ' 전주  한옥마을  여행 준비중입니다',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=475632922&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 대여는 천차만별입니다 기본 금액은 10000원 부터시작합니다 시간과 한복에따라서 가격이다릅니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 ',
#   'total_text': ' 전주  한옥마을  여행 준비중입니다  대여는 천차만별입니다 기본 금액은 10000원 부터시작합니다 시간과 한복에따라서 가격이다릅니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 '},
#  {'query': '전주 여행',
#   'no': 117,
#   'title': '1박2일  전주  커플 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=461495433&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 여행 에 대해 도움을 드릴게요 1 남자친구의 차를 이용할지 KTX를 이용할지에 대해서는 여러 가지 요소를 고려해보셔야 합니다 만약 교통체증이 예상되는 날짜라면 KTX를 이용하는 것이 편할 수 있습니다 또한 남자친구의 ',
#   'total_text': '1박2일  전주  커플 여행   전주 여행 에 대해 도움을 드릴게요 1 남자친구의 차를 이용할지 KTX를 이용할지에 대해서는 여러 가지 요소를 고려해보셔야 합니다 만약 교통체증이 예상되는 날짜라면 KTX를 이용하는 것이 편할 수 있습니다 또한 남자친구의 '},
#  {'query': '전주 여행',
#   'no': 118,
#   'title': ' 전주  가족  여행  코스 문의 드려요!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=482953663&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 ',
#   'total_text': ' 전주  가족  여행  코스 문의 드려요!  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 '},
#  {'query': '전주 여행',
#   'no': 119,
#   'title': '남해, 전주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=461982007&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '남해 전주 여행 가려는데 여행지와 맛집 추천좀 해주세요 보리암 다랭이굴 독일마을 전주 한옥마을빼고 두세개씩5명이서 갈곳 맛집 빨리추천해주세요 앞에 말했던곳은 갈꺼라서 추천안해주셔도 됩니다 전주여행 전주맛집 ',
#   'total_text': '남해, 전주 여행  남해 전주 여행 가려는데 여행지와 맛집 추천좀 해주세요 보리암 다랭이굴 독일마을 전주 한옥마을빼고 두세개씩5명이서 갈곳 맛집 빨리추천해주세요 앞에 말했던곳은 갈꺼라서 추천안해주셔도 됩니다 전주여행 전주맛집 '},
#  {'query': '전주 여행',
#   'no': 120,
#   'title': ' 전주여행  2박3일 경비',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90109&docId=471097881&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '보통 전주여행 2박3일 경비가 얼마정도 드나요 숙소는 1박에 13만원인데를 가려고 하는데 비싼건가요 질문에 도움이 되는 답변이 되셨길 바래요 2박3일 전주여행 예산 30만원 내외 숙소 13만원은 적당합니다 ',
#   'total_text': ' 전주여행  2박3일 경비 보통 전주여행 2박3일 경비가 얼마정도 드나요 숙소는 1박에 13만원인데를 가려고 하는데 비싼건가요 질문에 도움이 되는 답변이 되셨길 바래요 2박3일 전주여행 예산 30만원 내외 숙소 13만원은 적당합니다 '},
#  {'query': '전주 여행',
#   'no': 121,
#   'title': ' 전주여행  1박2일 코스질문요.',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=464365893&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 코스한번짜주실분 전라도쪽은 저도여행을간적이없어서 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 ',
#   'total_text': ' 전주여행  1박2일 코스질문요.  코스한번짜주실분 전라도쪽은 저도여행을간적이없어서 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 '},
#  {'query': '전주 여행',
#   'no': 122,
#   'title': ' 전주여행  3일',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=461053318&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 3일 간다면 여행 총 비용이 얼마 나올까요 전주 여행 의 총 비용은 여러 요소에 따라 달라지지만 일반적으로 다음과 같은 항목들이 포함됩니다 1 교통비 전주까지 이동하기 위한 교통비용이 있을 것입니다 이는 여행하는 ',
#   'total_text': ' 전주여행  3일  전주여행 3일 간다면 여행 총 비용이 얼마 나올까요 전주 여행 의 총 비용은 여러 요소에 따라 달라지지만 일반적으로 다음과 같은 항목들이 포함됩니다 1 교통비 전주까지 이동하기 위한 교통비용이 있을 것입니다 이는 여행하는 '},
#  {'query': '전주 여행',
#   'no': 123,
#   'title': ' 전주  1박2일  여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=483476433&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '5월 초에 기차타고 전주 갈 계획인데 전주에서 유명한 명소랑 맛집 추천 부탁드려요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 ',
#   'total_text': ' 전주  1박2일  여행  5월 초에 기차타고 전주 갈 계획인데 전주에서 유명한 명소랑 맛집 추천 부탁드려요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 '},
#  {'query': '전주 여행',
#   'no': 124,
#   'title': '강아지와함께  전주여행  가능한곳ㅜ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=454069765&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 갈껀데요 강아지 같이 동반할꺼라서요 혹시 강아지같이 갈수있는곳좀 알려주세요 맛집이랑 관광징 반려동물 1등 여행앱 반려생활입니다 하늘이 맑은 가을에 전주 여행 을 떠나시는군요 강아지랑 함께 더 좋은 추억 ',
#   'total_text': '강아지와함께  전주여행  가능한곳ㅜ  전주여행 갈껀데요 강아지 같이 동반할꺼라서요 혹시 강아지같이 갈수있는곳좀 알려주세요 맛집이랑 관광징 반려동물 1등 여행앱 반려생활입니다 하늘이 맑은 가을에 전주 여행 을 떠나시는군요 강아지랑 함께 더 좋은 추억 '},
#  {'query': '전주 여행',
#   'no': 125,
#   'title': ' 전주  완주  여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=456754318&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 완주 어느쪽을 여행하느냐에 따라 ',
#   'total_text': ' 전주  완주  여행   전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 완주 어느쪽을 여행하느냐에 따라 '},
#  {'query': '전주 여행',
#   'no': 126,
#   'title': ' 전주  3박4일  여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=459258161&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 부탁드립니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 ',
#   'total_text': ' 전주  3박4일  여행   부탁드립니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 '},
#  {'query': '전주 여행',
#   'no': 127,
#   'title': ' 전주 여행  갈려고 하는데',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=485524293&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 시작을 ',
#   'total_text': ' 전주 여행  갈려고 하는데  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 시작을 '},
#  {'query': '전주 여행',
#   'no': 128,
#   'title': ' 전주  당일치기 혼자  여행  코스 추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=483615087&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 박물관 미술관 지역 공간을 스토리로 엮어 안내하는 해설형 문화 코스 노쇼 방지를 위해 5천원 예약금만 결제하고 현장에서 5천천 원 상당 음료 기프티콘으로 환급 선착순 마감이라 전주 여행 계획 있으신 분들은 ',
#   'total_text': ' 전주  당일치기 혼자  여행  코스 추천  박물관 미술관 지역 공간을 스토리로 엮어 안내하는 해설형 문화 코스 노쇼 방지를 위해 5천원 예약금만 결제하고 현장에서 5천천 원 상당 음료 기프티콘으로 환급 선착순 마감이라 전주 여행 계획 있으신 분들은 '},
#  {'query': '전주 여행',
#   'no': 129,
#   'title': ' 전주여행 ..',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=473332244&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주는 대중교통이나 택시 이용하시는걸 ',
#   'total_text': ' 전주여행 ..  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주는 대중교통이나 택시 이용하시는걸 '},
#  {'query': '전주 여행',
#   'no': 130,
#   'title': ' 전주여행 코스좀짜주세요ㅜㅜ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=465655085&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 코스를 짜드릴 수 있습니다 전주는 역사적인 유적지와 전통문화가 빛나는 곳으로 유명한데요 먼저 전주한옥마을을 방문하시면 한옥의 아름다움을 느낄 수 있습니다 여행의 시작지라고 할 수 있는 전주한옥마을에서 ',
#   'total_text': ' 전주여행 코스좀짜주세요ㅜㅜ  전주여행 코스를 짜드릴 수 있습니다 전주는 역사적인 유적지와 전통문화가 빛나는 곳으로 유명한데요 먼저 전주한옥마을을 방문하시면 한옥의 아름다움을 느낄 수 있습니다 여행의 시작지라고 할 수 있는 전주한옥마을에서 '},
#  {'query': '전주 여행',
#   'no': 131,
#   'title': '추석  전주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=474841714&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '16 18일 전주 로 여행 가려고 하는데 그때 한옥마을같은 관광지들은 문 닫을까요 추석당일은 문을 닫습니다 전주 에도 이벤트가 진행중입니다 8 27 화 10 13 일 한국관광공사에서 숙박세일 페스타 이벤트가 진행중입니다 3만원 ',
#   'total_text': '추석  전주여행  16 18일 전주 로 여행 가려고 하는데 그때 한옥마을같은 관광지들은 문 닫을까요 추석당일은 문을 닫습니다 전주 에도 이벤트가 진행중입니다 8 27 화 10 13 일 한국관광공사에서 숙박세일 페스타 이벤트가 진행중입니다 3만원 '},
#  {'query': '전주 여행',
#   'no': 132,
#   'title': ' 전주여행  관련',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=469137468&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 주말인지 평일인지에 따라다릅니다 ',
#   'total_text': ' 전주여행  관련  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 주말인지 평일인지에 따라다릅니다 '},
#  {'query': '전주 여행',
#   'no': 133,
#   'title': ' 전주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=472340028&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '전주로 커플여행 가려고 하는데 추천 좀 해주세요 숙소는 잡았고 놀거리랑 맛집 등등 추천 해주시면 감사하겠습니다 한옥마을은 갈겁니다 답변이 도움되셨으면 좋겠습니다 한옥마을 전주한옥마을 전주 맛집 전주 놀거리 전주 여행 추천',
#   'total_text': ' 전주 여행  전주로 커플여행 가려고 하는데 추천 좀 해주세요 숙소는 잡았고 놀거리랑 맛집 등등 추천 해주시면 감사하겠습니다 한옥마을은 갈겁니다 답변이 도움되셨으면 좋겠습니다 한옥마을 전주한옥마을 전주 맛집 전주 놀거리 전주 여행 추천'},
#  {'query': '전주 여행',
#   'no': 134,
#   'title': '1박2일  전주여행 ~.~',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=407203201&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 질문하신 전주 여행 일정 관련 답변 드리도록 하겠습니다 여행가실 때 계획짜기 너무 귀찮죠 제가 전주에서 즐길 수 있는 1박 2일 여행을 준비해 보았어요 아래 일정을 참고해 보시고 즐거운 여행되시길 바라요 1일차 ',
#   'total_text': '1박2일  전주여행 ~.~  질문하신 전주 여행 일정 관련 답변 드리도록 하겠습니다 여행가실 때 계획짜기 너무 귀찮죠 제가 전주에서 즐길 수 있는 1박 2일 여행을 준비해 보았어요 아래 일정을 참고해 보시고 즐거운 여행되시길 바라요 1일차 '},
#  {'query': '전주 여행',
#   'no': 135,
#   'title': ' 전주 여행  가려고 하는데 1박2일vs2박3일',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=465668786&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 어떤게 적당할지 추천 좀 해주세요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 ',
#   'total_text': ' 전주 여행  가려고 하는데 1박2일vs2박3일  어떤게 적당할지 추천 좀 해주세요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 '},
#  {'query': '전주 여행',
#   'no': 136,
#   'title': ' 전주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=457210792&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 여행 을 가시려하는군요 그렇다면 전주에서 연인들이 제일 많이 찾는 곳들 추천해드리겠습니다 전주한옥마을 전주동물원 한국도로공사수목원 전주향교 덕진공원 ',
#   'total_text': ' 전주 여행   전주 여행 을 가시려하는군요 그렇다면 전주에서 연인들이 제일 많이 찾는 곳들 추천해드리겠습니다 전주한옥마을 전주동물원 한국도로공사수목원 전주향교 덕진공원 '},
#  {'query': '전주 여행',
#   'no': 137,
#   'title': ' 전주  2박3일 여행  비용',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=441096616&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 한옥마을은 입장료는 따로없습니다 기본 ',
#   'total_text': ' 전주  2박3일 여행  비용  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 한옥마을은 입장료는 따로없습니다 기본 '},
#  {'query': '전주 여행',
#   'no': 138,
#   'title': ' 전주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=449461461&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '이번주에 전주 여행 1박 2일로 처음 가는데 가볼데 추천 좀 해주세요 걷기 좋은데 위주로요 걷는 거 좋아해요 트레킹 좋아해요 전주여행 을 계획중이시군요 전주에는 다양한 볼거리들과 ',
#   'total_text': ' 전주 여행  이번주에 전주 여행 1박 2일로 처음 가는데 가볼데 추천 좀 해주세요 걷기 좋은데 위주로요 걷는 거 좋아해요 트레킹 좋아해요 전주여행 을 계획중이시군요 전주에는 다양한 볼거리들과 '},
#  {'query': '전주 여행',
#   'no': 139,
#   'title': '친구랑  전주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=452584751&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '친구랑 첫 전주여행 을 가보려고 합니다 가볼만한곳 호텔 맛집 추천해주세요 호텔은 시설이 괜찮고 깨끗했으면 좋겠어요 한옥이어도 괜찮아요 침대가 있는곳이면 더 좋겠어요 맛집은 양식 중식 일식 상관없습니다 비용도 1인당 ',
#   'total_text': '친구랑  전주여행  친구랑 첫 전주여행 을 가보려고 합니다 가볼만한곳 호텔 맛집 추천해주세요 호텔은 시설이 괜찮고 깨끗했으면 좋겠어요 한옥이어도 괜찮아요 침대가 있는곳이면 더 좋겠어요 맛집은 양식 중식 일식 상관없습니다 비용도 1인당 '},
#  {'query': '전주 여행',
#   'no': 140,
#   'title': ' 전주여행 코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=485639059&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 시작을 ',
#   'total_text': ' 전주여행 코스  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 시작을 '},
#  {'query': '전주 여행',
#   'no': 141,
#   'title': '2박3일  전주  크리스마스  여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=459344814&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 시작을 ',
#   'total_text': '2박3일  전주  크리스마스  여행   전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 시작을 '},
#  {'query': '전주 여행',
#   'no': 142,
#   'title': ' 전주여행  갈곳, 전시회 추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=438462586&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '제가 이번달 말에 남자친구랑 전주여행 을 가는데요 전주한옥마을만 가기엔 그래서 갈만한 곳 공방 전시회같은거 있음 추천부탁드려요 안녕하세요 질문하신 전주여행 관련 답변 드리도록 하겠습니다 전주로 놀러가시나 봅니다 ',
#   'total_text': ' 전주여행  갈곳, 전시회 추천 제가 이번달 말에 남자친구랑 전주여행 을 가는데요 전주한옥마을만 가기엔 그래서 갈만한 곳 공방 전시회같은거 있음 추천부탁드려요 안녕하세요 질문하신 전주여행 관련 답변 드리도록 하겠습니다 전주로 놀러가시나 봅니다 '},
#  {'query': '전주 여행',
#   'no': 143,
#   'title': ' 전주여행  코스 추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=261431923&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 여자친구랑 전주여행 을 갈예정인데 숙소를 전주 더클래식호텔로 잡고 1박2일 일정으로 여행을 가게되었습니다 근데 금요일 오후 5시쯤 전주에 도착예정이고 자가차가 없어 이동수단을 대중교통과 택시로 할예정입니다 ',
#   'total_text': ' 전주여행  코스 추천 안녕하세요 여자친구랑 전주여행 을 갈예정인데 숙소를 전주 더클래식호텔로 잡고 1박2일 일정으로 여행을 가게되었습니다 근데 금요일 오후 5시쯤 전주에 도착예정이고 자가차가 없어 이동수단을 대중교통과 택시로 할예정입니다 '},
#  {'query': '전주 여행',
#   'no': 144,
#   'title': '초등 6학년 210명  전주  일대 1박2일 수학 여행  코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=466708706&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 관광에 달인이신 전주달봉이님께서 코스 추천을 해 주시면 대단히 감사드리겠습니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 ',
#   'total_text': '초등 6학년 210명  전주  일대 1박2일 수학 여행  코스  전주 관광에 달인이신 전주달봉이님께서 코스 추천을 해 주시면 대단히 감사드리겠습니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 '},
#  {'query': '전주 여행',
#   'no': 145,
#   'title': ' 전주 여행 가는데 렌트를 하는게 좋을까',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=431515138&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 여행 가는데 렌트를 하는게 좋을까요 안녕하세요 천만 반려인과 함께하는 애견 동반 여행 플랫폼 하트독 입니다 전주는 작은 도시라서 택시로 이동을해도 크게 불편함이 없습니다 답변이 도움이 되셨다면 채택도 부탁드립니다 ',
#   'total_text': ' 전주 여행 가는데 렌트를 하는게 좋을까  전주 여행 가는데 렌트를 하는게 좋을까요 안녕하세요 천만 반려인과 함께하는 애견 동반 여행 플랫폼 하트독 입니다 전주는 작은 도시라서 택시로 이동을해도 크게 불편함이 없습니다 답변이 도움이 되셨다면 채택도 부탁드립니다 '},
#  {'query': '전주 여행',
#   'no': 146,
#   'title': ' 전주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=454611584&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 각각 거리가 가까운지 알고싶어요 추석에 여행예정입니다 그외 갈만한곳 추천해주세요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 ',
#   'total_text': ' 전주 여행   각각 거리가 가까운지 알고싶어요 추석에 여행예정입니다 그외 갈만한곳 추천해주세요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 '},
#  {'query': '전주 여행',
#   'no': 147,
#   'title': ' 전주여행 코스 좀 짜주세요 ~',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=407277228&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 질문하신 전주 여행 일정 관련 답변 드리도록 하겠습니다 친정 어머니와 딸과 다 함께 하는 여행 듣기만 해도 설레네요 아래 세 분께서 모두 즐길 수 있는 여행 일정을 준비해 보았어요 참고해 보시고 여행에 도움 되셨으면 ',
#   'total_text': ' 전주여행 코스 좀 짜주세요 ~  질문하신 전주 여행 일정 관련 답변 드리도록 하겠습니다 친정 어머니와 딸과 다 함께 하는 여행 듣기만 해도 설레네요 아래 세 분께서 모두 즐길 수 있는 여행 일정을 준비해 보았어요 참고해 보시고 여행에 도움 되셨으면 '},
#  {'query': '전주 여행',
#   'no': 148,
#   'title': ' 전주여행  추천 부탁 드립니다',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=438620129&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '2월 12 13일에 전주 여행 할려구 합니다 1박2일 가볼만한곳이랑 맛집 추천 부탁드립니다 감사합니다 전주맛집 여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여행 인플루언서 전주달봉이입니다 전주여행 ',
#   'total_text': ' 전주여행  추천 부탁 드립니다 2월 12 13일에 전주 여행 할려구 합니다 1박2일 가볼만한곳이랑 맛집 추천 부탁드립니다 감사합니다 전주맛집 여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여행 인플루언서 전주달봉이입니다 전주여행 '},
#  {'query': '전주 여행',
#   'no': 149,
#   'title': ' 전주여행  차가 필요한가요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=482799629&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 1박2일 전주여행 계획중입니다 서울에서 전주까지는 기차를타고갈건데 전주내에서 렌트를 해야할지 궁금합니다 참고로 전주한옥마을 포함해서 유명 관광지만 돌아볼계획입니다 전주여행 전주맛집 국내여행 ',
#   'total_text': ' 전주여행  차가 필요한가요 안녕하세요 1박2일 전주여행 계획중입니다 서울에서 전주까지는 기차를타고갈건데 전주내에서 렌트를 해야할지 궁금합니다 참고로 전주한옥마을 포함해서 유명 관광지만 돌아볼계획입니다 전주여행 전주맛집 국내여행 '},
#  {'query': '전주 여행',
#   'no': 150,
#   'title': ' 전주 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=436440960&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 제가 이번달 16일에 친구 3명하고 전주 로 여행 을 가는데 궁금한 게 많아서요 하나하나 답장해주시면 감사하겟습니다 1 여수에서 전주 KTX 왕복 기차표값이 얼마인가요 2 중2들이 전주 가서 놀 게 뭐가 잇을까요 3 ',
#   'total_text': ' 전주 여행   제가 이번달 16일에 친구 3명하고 전주 로 여행 을 가는데 궁금한 게 많아서요 하나하나 답장해주시면 감사하겟습니다 1 여수에서 전주 KTX 왕복 기차표값이 얼마인가요 2 중2들이 전주 가서 놀 게 뭐가 잇을까요 3 '},
#  {'query': '전주 여행',
#   'no': 151,
#   'title': '광주에서  전주  2박3일  여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=441966752&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 감사하겠습니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 버스터미널에서 내리셔서 ',
#   'total_text': '광주에서  전주  2박3일  여행   감사하겠습니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 버스터미널에서 내리셔서 '},
#  {'query': '전주 여행',
#   'no': 152,
#   'title': '[추천해주세요]  전주  당일치기  여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=441175638&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 추천해주세요 전주 당일치기 여행 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 ',
#   'total_text': '[추천해주세요]  전주  당일치기  여행   추천해주세요 전주 당일치기 여행 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 '},
#  {'query': '전주 여행',
#   'no': 153,
#   'title': '내일  전주  당일치기 부모님과  여행 을',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=451191859&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 바다는 군산 새만금 돌아보시면 ',
#   'total_text': '내일  전주  당일치기 부모님과  여행 을  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 바다는 군산 새만금 돌아보시면 '},
#  {'query': '전주 여행',
#   'no': 154,
#   'title': ' 전주여행  갈곳 추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=484366658&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 ',
#   'total_text': ' 전주여행  갈곳 추천  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 코스는 한옥마을에서부터 '},
#  {'query': '전주 여행',
#   'no': 155,
#   'title': ' 전주  2박3일 3명  여행  1인 경비',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=480452158&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 식비랑 교통비 감이 안잡혀서요 술은 마실건데 많이 안마셔서 술값으로는 한번마실 때 만원씩 쓸거같아요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 ',
#   'total_text': ' 전주  2박3일 3명  여행  1인 경비  식비랑 교통비 감이 안잡혀서요 술은 마실건데 많이 안마셔서 술값으로는 한번마실 때 만원씩 쓸거같아요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 '},
#  {'query': '전주 여행',
#   'no': 156,
#   'title': ' 전주 여행 코스 짜주세요! 많이 급합니다..!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=430866279&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 가족 여행 으로 전주 에 놀러가려는데요 당장 이번주 금요일에 가는데 어딜갈지 몰라서 숙소는 라한호텔로 잡았고 한옥마을 쪽을 가고 싶은데 별로 걷지 않으면서 카페투어는 아닌 여행 코스 짜주실 수 있나요 호캉스로 ',
#   'total_text': ' 전주 여행 코스 짜주세요! 많이 급합니다..! 안녕하세요 가족 여행 으로 전주 에 놀러가려는데요 당장 이번주 금요일에 가는데 어딜갈지 몰라서 숙소는 라한호텔로 잡았고 한옥마을 쪽을 가고 싶은데 별로 걷지 않으면서 카페투어는 아닌 여행 코스 짜주실 수 있나요 호캉스로 '},
#  {'query': '전주 여행',
#   'no': 157,
#   'title': '여자2명이서2박3일로  전주여행 질문',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=228331353&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 2박 3일로 전주 를 여행 하신다면 다음과 같은 일정을 추천해드립니다 Day 1 전주 한옥마을 전통 한옥 건물과 전통 문화를 경험할 수 있는 곳입니다 전주 향교 조선시대 교육기관인 향교를 볼 수 있습니다 전주 남부시장 전주 의 ',
#   'total_text': '여자2명이서2박3일로  전주여행 질문  2박 3일로 전주 를 여행 하신다면 다음과 같은 일정을 추천해드립니다 Day 1 전주 한옥마을 전통 한옥 건물과 전통 문화를 경험할 수 있는 곳입니다 전주 향교 조선시대 교육기관인 향교를 볼 수 있습니다 전주 남부시장 전주 의 '},
#  {'query': '전주 여행',
#   'no': 158,
#   'title': ' 전주 로 휴가갈건데  여행 코스 추천해주세요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8110301&docId=450793606&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 위의 일정은 참고용으로 제시한 것이며 여행 일정에 따라 조정할 수 있습니다 또한 음식점의 웨이팅 시간은 방문 시간과 요일에 따라 달라질 수 있으니 참고해주세요 즐거운 전주 여행 되시길 바랍니다 ',
#   'total_text': ' 전주 로 휴가갈건데  여행 코스 추천해주세요  위의 일정은 참고용으로 제시한 것이며 여행 일정에 따라 조정할 수 있습니다 또한 음식점의 웨이팅 시간은 방문 시간과 요일에 따라 달라질 수 있으니 참고해주세요 즐거운 전주 여행 되시길 바랍니다 '},
#  {'query': '전주 여행',
#   'no': 159,
#   'title': ' 전주 여행 코스!!!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=432706708&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 이미 전주여행 을 마치고 복귀하셨을 것 같네요 저희도 지난주에 당일코스로 전주에 다녀왔는데요 주말이라서 그런지 차들도 많고 관광지에는 사람들도 많아서 생각처럼 많이 둘러보지 못해서 아쉽더라고요 최소한 1박2일 ',
#   'total_text': ' 전주 여행 코스!!!  이미 전주여행 을 마치고 복귀하셨을 것 같네요 저희도 지난주에 당일코스로 전주에 다녀왔는데요 주말이라서 그런지 차들도 많고 관광지에는 사람들도 많아서 생각처럼 많이 둘러보지 못해서 아쉽더라고요 최소한 1박2일 '},
#  {'query': '전주 여행',
#   'no': 160,
#   'title': ' 전주  1박2일  여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=444409591&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 대둔산 케이블카 주말에 사람많겠죠 괜찮은 코스 추천해주세요 전주 여행 을 계획하시는 건가요 좋은 선택입니다 전주는 한국의 전통문화가 잘 보존되어 있는 곳으로 유명합니다 한옥마을은 물론 전주의 다양한 문화유산을 ',
#   'total_text': ' 전주  1박2일  여행   대둔산 케이블카 주말에 사람많겠죠 괜찮은 코스 추천해주세요 전주 여행 을 계획하시는 건가요 좋은 선택입니다 전주는 한국의 전통문화가 잘 보존되어 있는 곳으로 유명합니다 한옥마을은 물론 전주의 다양한 문화유산을 '},
#  {'query': '전주 여행',
#   'no': 161,
#   'title': ' 전주여행 팀조뮤ㅠ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60203&docId=465427767&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 1박2일가는데가기좋은곳이랑맛집좀알려주세요 안녕하세요 서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 김선용 변호사입니다 알아보는것이 어려우시다면 인스타그램에 전주라고 검색 하셔서 ',
#   'total_text': ' 전주여행 팀조뮤ㅠ  전주여행 1박2일가는데가기좋은곳이랑맛집좀알려주세요 안녕하세요 서울지방변호사회 소속으로 지식iN 법률상담을 진행하고 있는 김선용 변호사입니다 알아보는것이 어려우시다면 인스타그램에 전주라고 검색 하셔서 '},
#  {'query': '전주 여행',
#   'no': 162,
#   'title': ' 전주  한옥마을 당일치기  여행  질문',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=439825862&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여수제주도맛집 여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 1 7000 8000원 2 흐노니 마시랑게 전망 달곰 3 ',
#   'total_text': ' 전주  한옥마을 당일치기  여행  질문  전주여수제주도맛집 여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 1 7000 8000원 2 흐노니 마시랑게 전망 달곰 3 '},
#  {'query': '전주 여행',
#   'no': 163,
#   'title': ' 전주  혼자2박3일 여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=224588034&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 아무래도 사람이 많으면 맛집같은곳에서 혼자못먹을것같아서 5월 중순은 전주 여행 을 즐기기 좋은 계절입니다 하지만 현재는 코로나19로 인해 여행객이 줄어들고 있으므로 사람이 많지 않을 것으로 예상됩니다 전주는 맛집이 ',
#   'total_text': ' 전주  혼자2박3일 여행   아무래도 사람이 많으면 맛집같은곳에서 혼자못먹을것같아서 5월 중순은 전주 여행 을 즐기기 좋은 계절입니다 하지만 현재는 코로나19로 인해 여행객이 줄어들고 있으므로 사람이 많지 않을 것으로 예상됩니다 전주는 맛집이 '},
#  {'query': '전주 여행',
#   'no': 164,
#   'title': '2박3일  전주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=475523884&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '이번주 토 월 2박3일 여자친구와 전주여행 을 가는데 여행경로 좀 알려주세요 토요일엔 비가 온다고 하는데 실내데이트 가능한곳도 알려주시면 감사하겠습니다 숙소는 전주한옥마을 근처에 잡았습니다 토 한옥마을 구경 후 ',
#   'total_text': '2박3일  전주여행  이번주 토 월 2박3일 여자친구와 전주여행 을 가는데 여행경로 좀 알려주세요 토요일엔 비가 온다고 하는데 실내데이트 가능한곳도 알려주시면 감사하겠습니다 숙소는 전주한옥마을 근처에 잡았습니다 토 한옥마을 구경 후 '},
#  {'query': '전주 여행',
#   'no': 165,
#   'title': '고등학교친구들과  전주여행  당일치기',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=466553507&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '지금 고등학교3학년 친구들과 함께 4월달에 전주여행 을 당일치기로 갈 예정인데 부모님께 뭐라고 말씀드리면 허락을 받을수 있을까요 고등학교 시절 친구들과의 소중한 추억을 만들기 위해 전주 여행 을 다녀오기로 했습니다 전주는 ',
#   'total_text': '고등학교친구들과  전주여행  당일치기 지금 고등학교3학년 친구들과 함께 4월달에 전주여행 을 당일치기로 갈 예정인데 부모님께 뭐라고 말씀드리면 허락을 받을수 있을까요 고등학교 시절 친구들과의 소중한 추억을 만들기 위해 전주 여행 을 다녀오기로 했습니다 전주는 '},
#  {'query': '전주 여행',
#   'no': 166,
#   'title': ' 전주여행  갈만한곳(숙소/한옥마을게스트하우스)',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=230766988&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 가족들과 함께 전주여행 을 가려고 합니다 한옥마을로 유명한 전주여행 을 꼭 한번 해보고 싶어했었는데 이번을 기회로 꼭 다녀와보려구요 전라도 음식이 맛있다고 전주에 가면 전라도의 대표음식도 먹어볼뿐만 아니라 맛집도 ',
#   'total_text': ' 전주여행  갈만한곳(숙소/한옥마을게스트하우스) 안녕하세요 가족들과 함께 전주여행 을 가려고 합니다 한옥마을로 유명한 전주여행 을 꼭 한번 해보고 싶어했었는데 이번을 기회로 꼭 다녀와보려구요 전라도 음식이 맛있다고 전주에 가면 전라도의 대표음식도 먹어볼뿐만 아니라 맛집도 '},
#  {'query': '전주 여행',
#   'no': 167,
#   'title': ' 전주여행 갈껀데 월요일 휴무가 많나요?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=467372054&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 걱정안하셔도되셔요 대부분 오픈합니다 ',
#   'total_text': ' 전주여행 갈껀데 월요일 휴무가 많나요?  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 걱정안하셔도되셔요 대부분 오픈합니다 '},
#  {'query': '전주 여행',
#   'no': 168,
#   'title': ' 전주여행  볼거리',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=429817174&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '이번주 전주여행 가는데 볼거리 맛집 등 알려주세요 전주에서 가볼만한 곳들 추천해드리겠습니다 전주한옥마을 전주동물원 한국도로공사수목원 덕진공원 전주난장 ',
#   'total_text': ' 전주여행  볼거리 이번주 전주여행 가는데 볼거리 맛집 등 알려주세요 전주에서 가볼만한 곳들 추천해드리겠습니다 전주한옥마을 전주동물원 한국도로공사수목원 덕진공원 전주난장 '},
#  {'query': '전주 여행',
#   'no': 169,
#   'title': ' 전주 여행 가려는데..',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=432785295&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 한옥마을 근처에서 숙박하며 여행 한다면 어디어디 가고 어떤 맛집이 좋은지 버스나 택시타고 조금만 나가도 되는 가볼만한 곳이 어딘지 등등 추천해주세요 2 그외에 다른곳 어디 ',
#   'total_text': ' 전주 여행 가려는데..  전주 한옥마을 근처에서 숙박하며 여행 한다면 어디어디 가고 어떤 맛집이 좋은지 버스나 택시타고 조금만 나가도 되는 가볼만한 곳이 어딘지 등등 추천해주세요 2 그외에 다른곳 어디 '},
#  {'query': '전주 여행',
#   'no': 170,
#   'title': ' 전주  뚜벅이 대중교통  여행  1박 2일 코스 어떻게 짜면... ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=419417393&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 질문하신 전주 여행 코스 관련 답변드리겠습니다 전주로의 커플 여행을 계획 중이시군요 전주의 추천 명소와 맛집들을 포함해 여다에서 맞춤형 1박 2일 전주 여행 일정을 준비했어요 아래 첨부된 일정을 확인해 보시고 즐거운 ',
#   'total_text': ' 전주  뚜벅이 대중교통  여행  1박 2일 코스 어떻게 짜면...   질문하신 전주 여행 코스 관련 답변드리겠습니다 전주로의 커플 여행을 계획 중이시군요 전주의 추천 명소와 맛집들을 포함해 여다에서 맞춤형 1박 2일 전주 여행 일정을 준비했어요 아래 첨부된 일정을 확인해 보시고 즐거운 '},
#  {'query': '전주 여행',
#   'no': 171,
#   'title': ' 전주 여행  코스 및 일정 추천 부탁드려요(토요일 하루)',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=443982849&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 일정이 괜찮은지 수정이 필요한 부분이 있는지 인근 맛집 등은 또 있는지 등등 의견 부탁 드립니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 ',
#   'total_text': ' 전주 여행  코스 및 일정 추천 부탁드려요(토요일 하루)  일정이 괜찮은지 수정이 필요한 부분이 있는지 인근 맛집 등은 또 있는지 등등 의견 부탁 드립니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 '},
#  {'query': '전주 여행',
#   'no': 172,
#   'title': ' 전주여행  갈만한곳있을까요?',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=467434913&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 여행 을 즐길 만한 곳은 많이 있습니다 전주한옥마을은 한국 전통 가옥인 한옥이 보존되어 있는 곳으로 유명하며 전통 음식과 공예품을 즐길 수 있습니다 또한 전주 남부시장은 현지인들이 찾는 전통 시장으로 신선한 ',
#   'total_text': ' 전주여행  갈만한곳있을까요?  전주 여행 을 즐길 만한 곳은 많이 있습니다 전주한옥마을은 한국 전통 가옥인 한옥이 보존되어 있는 곳으로 유명하며 전통 음식과 공예품을 즐길 수 있습니다 또한 전주 남부시장은 현지인들이 찾는 전통 시장으로 신선한 '},
#  {'query': '전주 여행',
#   'no': 173,
#   'title': '전라도  전주여행 ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=428170195&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 에 여행 을 가려고하는데 한번도안가봐서요 1박2일이나 2박3일 있을예정인데 가볼만한곳 추천받아용 체험도좋구용 전주 에서 가볼만한 곳들 추천해드리겠습니다 전주 한옥마을 ',
#   'total_text': '전라도  전주여행   전주 에 여행 을 가려고하는데 한번도안가봐서요 1박2일이나 2박3일 있을예정인데 가볼만한곳 추천받아용 체험도좋구용 전주 에서 가볼만한 곳들 추천해드리겠습니다 전주 한옥마을 '},
#  {'query': '전주 여행',
#   'no': 174,
#   'title': ' 전주 여행  코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=452031214&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '아침으로 전주 현대옥 본점 가서 먹고 점심으로는 전주 비빔소리를 가려고 하는데 현대옥과 비빔소리 중간에 어디 구경할 곳이나 갈만한 곳 없을까요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 ',
#   'total_text': ' 전주 여행  코스 아침으로 전주 현대옥 본점 가서 먹고 점심으로는 전주 비빔소리를 가려고 하는데 현대옥과 비빔소리 중간에 어디 구경할 곳이나 갈만한 곳 없을까요 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 '},
#  {'query': '전주 여행',
#   'no': 175,
#   'title': ' 전주여행 !',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=459792395&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '크리스마스에 단둘이서 당일치기로 전주여행 하기로했습니다 고등학생인데요 어느정도 들고가는게맞고 전주는 할게 뭐뭐 있을까요 제대로 답변해주세요 대학로와 투어공연하는 연극 추천해 드릴께요 ',
#   'total_text': ' 전주여행 ! 크리스마스에 단둘이서 당일치기로 전주여행 하기로했습니다 고등학생인데요 어느정도 들고가는게맞고 전주는 할게 뭐뭐 있을까요 제대로 답변해주세요 대학로와 투어공연하는 연극 추천해 드릴께요 '},
#  {'query': '전주 여행',
#   'no': 176,
#   'title': ' 전주 여행 코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=402381652&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 일정에 질문자님께서 봐둔 곳 모두 반양하기에 시간상 무리가 있을 거 같아 꼭 가고 싶은 곳을 넣어 일정을 만들어 보았습니다 1일차 가운데집 점심 전주한지박물관 관광 전주수목원 관광 오목대 관광 교동다윈 ',
#   'total_text': ' 전주 여행 코스  전주여행 일정에 질문자님께서 봐둔 곳 모두 반양하기에 시간상 무리가 있을 거 같아 꼭 가고 싶은 곳을 넣어 일정을 만들어 보았습니다 1일차 가운데집 점심 전주한지박물관 관광 전주수목원 관광 오목대 관광 교동다윈 '},
#  {'query': '전주 여행',
#   'no': 177,
#   'title': ' 전주 에  여행 가는데 오션뷰 카페 추천해주세요.',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=468083904&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 아쉽게도 전주이는 바다가없어서 ',
#   'total_text': ' 전주 에  여행 가는데 오션뷰 카페 추천해주세요.  전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 아쉽게도 전주이는 바다가없어서 '},
#  {'query': '전주 여행',
#   'no': 178,
#   'title': '1박2일  전주  혼자  여행  코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=224123446&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 질문하신 전주 여행 정보 정리해봤습니다 참고해주세요 전주에서 가볼만한 곳 덕진공원 추천 덕진공원이 전주터미널에서 가장 가까운 곳이에요 산책하기에 좋은 호수공원이에요 덕진공원을 생략하고 곧바로 남부시장과 ',
#   'total_text': '1박2일  전주  혼자  여행  코스  질문하신 전주 여행 정보 정리해봤습니다 참고해주세요 전주에서 가볼만한 곳 덕진공원 추천 덕진공원이 전주터미널에서 가장 가까운 곳이에요 산책하기에 좋은 호수공원이에요 덕진공원을 생략하고 곧바로 남부시장과 '},
#  {'query': '전주 여행',
#   'no': 179,
#   'title': ' 전주 여행 코스!!!',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=223302720&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 이미 전주여행 을 마치고 복귀하셨을 것 같네요 저희도 지난주에 당일코스로 전주에 다녀왔는데요 주말이라서 그런지 차들도 많고 관광지에는 사람들도 많아서 생각처럼 많이 둘러보지 못해서 아쉽더라고요 최소한 1박2일 ',
#   'total_text': ' 전주 여행 코스!!!  이미 전주여행 을 마치고 복귀하셨을 것 같네요 저희도 지난주에 당일코스로 전주에 다녀왔는데요 주말이라서 그런지 차들도 많고 관광지에는 사람들도 많아서 생각처럼 많이 둘러보지 못해서 아쉽더라고요 최소한 1박2일 '},
#  {'query': '전주 여행',
#   'no': 180,
#   'title': ' 전주 여행  코스 동선 좀 짜주세요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=458306197&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 숙소는 완산구 서신동입니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 1 한옥마을 ',
#   'total_text': ' 전주 여행  코스 동선 좀 짜주세요  숙소는 완산구 서신동입니다 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 1 한옥마을 '},
#  {'query': '전주 여행',
#   'no': 181,
#   'title': '뚜벅이  여행 으로  전주  가려는데 한옥마을 근처 짐... ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=428889568&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 이용하시면 원하는 장소에서 장소로 짐 운송이 가능합니다 가격도 저렴하고 앱을 통해 실시간으로 주문 및 현황 확인까지 가능해 여행 중 편리하게 이용이 가능하니 전주 뚜벅이여행 시 참고해보세요 즐거운 전주여행 되시길 바랄게요',
#   'total_text': '뚜벅이  여행 으로  전주  가려는데 한옥마을 근처 짐...   이용하시면 원하는 장소에서 장소로 짐 운송이 가능합니다 가격도 저렴하고 앱을 통해 실시간으로 주문 및 현황 확인까지 가능해 여행 중 편리하게 이용이 가능하니 전주 뚜벅이여행 시 참고해보세요 즐거운 전주여행 되시길 바랄게요'},
#  {'query': '전주 여행',
#   'no': 182,
#   'title': ' 전주 여행 코스 질문드려요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=149726141&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 이상은 제가 전주여행 문의하는 분들께 통상 안내해 드리는 정보입니다 질문하신 분께 간단히 요약해 드리면 먼저 위 사이트 들어가셔서 방 예약하시고 오전에 ',
#   'total_text': ' 전주 여행 코스 질문드려요  이상은 제가 전주여행 문의하는 분들께 통상 안내해 드리는 정보입니다 질문하신 분께 간단히 요약해 드리면 먼저 위 사이트 들어가셔서 방 예약하시고 오전에 '},
#  {'query': '전주 여행',
#   'no': 183,
#   'title': ' 전주 여행  및 코스 질문 내공있어요~100',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=279859546&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '부산에서 전주여행 을 가려고 합니다 자차 여행이 아닌 버스위주로 가려고 합니다 그리고 전주만 가는것이아니라 전주갔다가 전주에서 가깝거나 버스로 1 2시간 정도 갈수있는 다른 지역도 여행 가고 싶은데 여행 많이 다니시는분들 ',
#   'total_text': ' 전주 여행  및 코스 질문 내공있어요~100 부산에서 전주여행 을 가려고 합니다 자차 여행이 아닌 버스위주로 가려고 합니다 그리고 전주만 가는것이아니라 전주갔다가 전주에서 가깝거나 버스로 1 2시간 정도 갈수있는 다른 지역도 여행 가고 싶은데 여행 많이 다니시는분들 '},
#  {'query': '전주 여행',
#   'no': 184,
#   'title': '제가  전주여행 을 갔는데여',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80101&docId=457532341&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '제가 왜그런진 모르겠지만 그냥 전라도 사투리 듣기 싫더라구요 억양이 쎄서그런감 좀 듣기가 거북했는데 전주여행 갔었는데 무슨일인진모르겠지만 사람들 전라도 사투리 1도 안쓰던데요 쫌 의외였어요 전라북도 전주시 아닌가요 ',
#   'total_text': '제가  전주여행 을 갔는데여 제가 왜그런진 모르겠지만 그냥 전라도 사투리 듣기 싫더라구요 억양이 쎄서그런감 좀 듣기가 거북했는데 전주여행 갔었는데 무슨일인진모르겠지만 사람들 전라도 사투리 1도 안쓰던데요 쫌 의외였어요 전라북도 전주시 아닌가요 '},
#  {'query': '전주 여행',
#   'no': 185,
#   'title': '이번에 태교 여행 으로 2박3일 놀러가려고 하는데 강아지... ',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=440802188&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 숙소잡기가 힘드시다면 바닷가가 ',
#   'total_text': '이번에 태교 여행 으로 2박3일 놀러가려고 하는데 강아지...   전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 전주여행 숙소잡기가 힘드시다면 바닷가가 '},
#  {'query': '전주 여행',
#   'no': 186,
#   'title': ' 전주여행  코스 좀 알려주세요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=387443906&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 전주 로 당일치기 여행 할껀데 코스 좀 짜주세요 전주 동물원 전주 한옥마을 전주 수목원 팔복예술공장 전주 드림랜드 당일치기로 갈껀데 코스좀알려주세요 자가용으로 이동하신다면 아래와 같은 코스가 시간을 아낄 수 ',
#   'total_text': ' 전주여행  코스 좀 알려주세요 안녕하세요 전주 로 당일치기 여행 할껀데 코스 좀 짜주세요 전주 동물원 전주 한옥마을 전주 수목원 팔복예술공장 전주 드림랜드 당일치기로 갈껀데 코스좀알려주세요 자가용으로 이동하신다면 아래와 같은 코스가 시간을 아낄 수 '},
#  {'query': '전주 여행',
#   'no': 187,
#   'title': ' 전주  1박2일  여행 가는데 코스추천부탁드려요~^^',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=420277757&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '남자친구와 생일여행으로 전주여행 을가는데 전주는 처음이라 좋은 코스있으면 추천좀 부탁드립니다 숙소는 전주 한옥마을 도보 10거리에 잡았고 자차 있어서 이동은 문제없습니다 맛집도 추천 부탁드려요 안녕하세요 AI ',
#   'total_text': ' 전주  1박2일  여행 가는데 코스추천부탁드려요~^^ 남자친구와 생일여행으로 전주여행 을가는데 전주는 처음이라 좋은 코스있으면 추천좀 부탁드립니다 숙소는 전주 한옥마을 도보 10거리에 잡았고 자차 있어서 이동은 문제없습니다 맛집도 추천 부탁드려요 안녕하세요 AI '},
#  {'query': '전주 여행',
#   'no': 188,
#   'title': '당일치기  전주여행 코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=276243421&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 처음으로 전주여행 을 가는거라서 아는 것이 많이 없어요 일단 전주 한옥마을에서 한복을 빌려서 한옥마을 전동성당이랑 경기전 그리고 자만벽화마을 까지 가기로 정했는데 또 다른 놀러갈 곳을 찾진 못했어요 전주에 한옥마을과 ',
#   'total_text': '당일치기  전주여행 코스  처음으로 전주여행 을 가는거라서 아는 것이 많이 없어요 일단 전주 한옥마을에서 한복을 빌려서 한옥마을 전동성당이랑 경기전 그리고 자만벽화마을 까지 가기로 정했는데 또 다른 놀러갈 곳을 찾진 못했어요 전주에 한옥마을과 '},
#  {'query': '전주 여행',
#   'no': 189,
#   'title': ' 전주 여행  전연령 렌트카 추천',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8110203&docId=477031265&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '이번에 전주 여행 2박3일로 가는 저는 21살 만으로 만 19세입니다 전주 전연령 자동차 추천좀 부탁드리겠습니다 그리고 가격도 2일 렌트하면 총 어느정도 나올까요 전주에서 21세 이상 렌트 가능한 자동차를 찾아보세요 가격은 ',
#   'total_text': ' 전주 여행  전연령 렌트카 추천 이번에 전주 여행 2박3일로 가는 저는 21살 만으로 만 19세입니다 전주 전연령 자동차 추천좀 부탁드리겠습니다 그리고 가격도 2일 렌트하면 총 어느정도 나올까요 전주에서 21세 이상 렌트 가능한 자동차를 찾아보세요 가격은 '},
#  {'query': '전주 여행',
#   'no': 190,
#   'title': '(급합니다ㅠㅠ)  전주 여행 코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=230653752&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 코스 추천드립니다 안녕하세요 여행전문블로거 쭈니아빠입니다 방학을 맞아서 친구분들과 전주여행 을 준비하고 계시네요 전주는 한옥마을을 중심으로 가볼만한 곳이 많죠 터미널에서 버스를 타고 한옥마을에 ',
#   'total_text': '(급합니다ㅠㅠ)  전주 여행 코스  전주여행 코스 추천드립니다 안녕하세요 여행전문블로거 쭈니아빠입니다 방학을 맞아서 친구분들과 전주여행 을 준비하고 계시네요 전주는 한옥마을을 중심으로 가볼만한 곳이 많죠 터미널에서 버스를 타고 한옥마을에 '},
#  {'query': '전주 여행',
#   'no': 191,
#   'title': ' 전주 여행  비용',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=389274491&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '안녕하세요 전주 로 여행 가려는 학생입니다 수원살고 있고요 2박3일 3박으로 3 4명이서 가려하는데 비용이 어느정도 나올까요 수원에서 전주 까지는 자가용으로도 2시간 정도 걸리는 코스인데요 대중교통으로 간다라면 조금 더 ',
#   'total_text': ' 전주 여행  비용 안녕하세요 전주 로 여행 가려는 학생입니다 수원살고 있고요 2박3일 3박으로 3 4명이서 가려하는데 비용이 어느정도 나올까요 수원에서 전주 까지는 자가용으로도 2시간 정도 걸리는 코스인데요 대중교통으로 간다라면 조금 더 '},
#  {'query': '전주 여행',
#   'no': 192,
#   'title': ' 전주  1박2일  여행 코스 추천 및 조언해주세요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=467438359&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '가고싶은곳 전주한옥마을 경기전 전주난장 전주국립박물관 전주동물원 이동수단 자동차 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 ',
#   'total_text': ' 전주  1박2일  여행 코스 추천 및 조언해주세요 가고싶은곳 전주한옥마을 경기전 전주난장 전주국립박물관 전주동물원 이동수단 자동차 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 '},
#  {'query': '전주 여행',
#   'no': 193,
#   'title': ' 전주  한옥마을에 남자 혼자  여행 을 갈 예정입니다.',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=441064844&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 욕조는 저도 굉장히 무리한 질문인것 같지만 혹시나해서 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 ',
#   'total_text': ' 전주  한옥마을에 남자 혼자  여행 을 갈 예정입니다.  욕조는 저도 굉장히 무리한 질문인것 같지만 혹시나해서 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 '},
#  {'query': '전주 여행',
#   'no': 194,
#   'title': ' 전주 여행 코스 추천좀요',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90110&docId=414983842&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주 여행 코스 추천하세염 전주동물원 걍기전 전주한옥마을 덕진연못으로 가보세요',
#   'total_text': ' 전주 여행 코스 추천좀요  전주 여행 코스 추천하세염 전주동물원 걍기전 전주한옥마을 덕진연못으로 가보세요'},
#  {'query': '전주 여행',
#   'no': 195,
#   'title': ' 전주여행  순서좀 알려주세요~',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=223850942&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 을 하려고 하는데요 덕진공원 전주동물원 한옥마을 남부시장을 가려고 합니다 전주시외버스공용터미널에서 가까운 순서가 어떻게 될까요 그리고 근처에 가까운 바닷가는 어디 인가요 또 이 외에 구경할 좋은 곳도 ',
#   'total_text': ' 전주여행  순서좀 알려주세요~  전주여행 을 하려고 하는데요 덕진공원 전주동물원 한옥마을 남부시장을 가려고 합니다 전주시외버스공용터미널에서 가까운 순서가 어떻게 될까요 그리고 근처에 가까운 바닷가는 어디 인가요 또 이 외에 구경할 좋은 곳도 '},
#  {'query': '전주 여행',
#   'no': 196,
#   'title': ' 전주 여행  음식점',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=312190870&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '25일날 전주여행 을 가는데 전주동물원이랑 레일바이크 아중저수지 오목대주변에 맛집이나 음식 먹을만한거 있으면 추천해주세여 내공100드려여 추가로 터미널쪽에도 알려주시면 고맙습니다 답변 한옥마을에 에루화 떡갈비 ',
#   'total_text': ' 전주 여행  음식점 25일날 전주여행 을 가는데 전주동물원이랑 레일바이크 아중저수지 오목대주변에 맛집이나 음식 먹을만한거 있으면 추천해주세여 내공100드려여 추가로 터미널쪽에도 알려주시면 고맙습니다 답변 한옥마을에 에루화 떡갈비 '},
#  {'query': '전주 여행',
#   'no': 197,
#   'title': ' 전주 여행  가려 합니다~',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=77622541&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': '금요일 저녁에서 토요일까지 1박 2일로 전주 여행 을 가려고 합니다 1 한옥마을에서 터미널 역 둘중에 어느 쪽이 더 가까운가요 2 시외버스터미널과 역은 얼마나 먼가요 3 한옥마을 근처 찜질방에서 묵을 계획인데 어떤 곳이 ',
#   'total_text': ' 전주 여행  가려 합니다~ 금요일 저녁에서 토요일까지 1박 2일로 전주 여행 을 가려고 합니다 1 한옥마을에서 터미널 역 둘중에 어느 쪽이 더 가까운가요 2 시외버스터미널과 역은 얼마나 먼가요 3 한옥마을 근처 찜질방에서 묵을 계획인데 어떤 곳이 '},
#  {'query': '전주 여행',
#   'no': 198,
#   'title': ' 전주  1박2일  여행 코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=224946421&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 질문하신 내용을 토대로 1박2일 일정으로 전주 여행 코스를 정리했습니다 참고해주세요 1일차 오후 전주 한옥마을 및 주변 1일차 저녁 전주 남부시장 야시장 한옥마을 야경즐기기 2일차 오전 덕진공원 2일차 오후 전주동물원 ',
#   'total_text': ' 전주  1박2일  여행 코스  질문하신 내용을 토대로 1박2일 일정으로 전주 여행 코스를 정리했습니다 참고해주세요 1일차 오후 전주 한옥마을 및 주변 1일차 저녁 전주 남부시장 야시장 한옥마을 야경즐기기 2일차 오전 덕진공원 2일차 오후 전주동물원 '},
#  {'query': '전주 여행',
#   'no': 199,
#   'title': ' 전주여행 코스',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=307214130&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 전주여행 코스 전주맛집 자세한 정보는 https blog naver com sjh920519 전주캐릭터 전주여행 할땐 전주달봉이입니다 전주숙박할인이나 좀더 궁금사항있으시면 네임카드 블로그 질문게시판에 남겨주세요 전주한옥마을맛집 ',
#   'total_text': ' 전주여행 코스  전주여행 코스 전주맛집 자세한 정보는 https blog naver com sjh920519 전주캐릭터 전주여행 할땐 전주달봉이입니다 전주숙박할인이나 좀더 궁금사항있으시면 네임카드 블로그 질문게시판에 남겨주세요 전주한옥마을맛집 '},
#  {'query': '전주 여행',
#   'no': 200,
#   'title': ' 전주  1박2일  여행  질문',
#   'link': 'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121305&docId=288104678&qb=7KCE7KO8IOyXrO2WiQ==&enc=utf8',
#   'description': ' 좀더 궁금사항있으시면 네임카드 블로그 질문게시판에 남겨주세요 감사합니다 전주한옥마을 전주맛집 전주여행 전주숙박할인 전주한옥마을숙박 전주여행 정보는 네임카드 타고오세요 ',
#   'total_text': ' 전주  1박2일  여행  질문  좀더 궁금사항있으시면 네임카드 블로그 질문게시판에 남겨주세요 감사합니다 전주한옥마을 전주맛집 전주여행 전주숙박할인 전주한옥마을숙박 전주여행 정보는 네임카드 타고오세요 '}]

# %%
import time
result_total = []  # 모든 검색 결과
queries = ['전주 여행','경주 여행']
max_start = 5
for query in queries:
    for start in range(1, max_start+1):
        print(start, query, '읽는 중')
        result_total.extend(get_search_element_return(query, start))
        time.sleep(0.5)
df = pd.DataFrame(result_total)
df.to_csv('data/naver.csv', index=False)  # encoding='cp949'
# Out:
# 1 전주 여행 읽는 중
# 2 전주 여행 읽는 중
# 3 전주 여행 읽는 중
# 4 전주 여행 읽는 중
# 5 전주 여행 읽는 중
# 1 경주 여행 읽는 중
# 2 경주 여행 읽는 중
# 3 경주 여행 읽는 중
# 4 경주 여행 읽는 중
# 5 경주 여행 읽는 중

# %% [markdown]
# # 2. 품사태깅 백업
# - query, no, token, pos

# %%
import pandas as pd
df = pd.read_csv('data/naver.csv')
df.tail(1)
# Out:
#      query   no     title                                               link  \
# 999  경주 여행  500   경주여행 !!  https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                            description  \
# 999   경주 여행 을 가려고 하는데 혹시 경주에 폴라로이드 카메라 대여 할 수 있는곳이나...
#
#                                             total_text
# 999   경주여행 !!  경주 여행 을 가려고 하는데 혹시 경주에 폴라로이드 카메라 대여 ...

# %%
df_list = df[['query', 'no','total_text']].values.tolist()  # 배열로 만들어서 리스트로 변환
df_list[::500]
# Out:
# [['전주 여행',
#   1,
#   '25년10월5,6,7일  전주여행   전주여행 가볼만한 곳 추천부탁드립니다 25년 10월 초 전주여행 아이들과 함께 가기 좋은 시점이에요 추석에는 문 연 곳이 적을 수 있지만 전주 한옥마을이나 전주비빔밥 맛집은 추천해용 차는 밀릴 가능성이 높으니 미리 출발하는 '],
#  ['경주 여행',
#   1,
#   'APEC 기간  경주여행  APEC 기간 경주여행 어떻게 생각하시나요 APEC 기간에 경주여행 은 좋은 방법이에요 역사와 문화가 가득한 도시에서 특별한 경험을 할 수 있을 거에요 즐거운 여행 되세요 ']]

# %%
from mecab import MeCab
analyzer = MeCab()
stopwords = {'전주', '경주','여행'}
postagged_list = []  # query, no, token, pos 딕셔너리 list
for i, row in enumerate(df_list):
    query = row[0]
    no    = row[1]
    text  = row[2]
    tagged_text = analyzer.pos(text)
#     if i%250==0:
#         print("{}의 {}번째 품사태깅결과 : {}개".format(query, no, len(tagged_text)))
#         print(tagged_text[5:15])
    for token, pos in tagged_text:
        # if token not in stopwords and pos in select_pos: # 불용어제외한 명사
        if token not in stopwords: # 불용어 제외.
            postagged_list.append({
                'query':query,
                'no':no,
                'token':token,
                'pos':pos
            })
df_postagged = pd.DataFrame(postagged_list)
df_postagged.to_csv('data/naver_pos.csv', index=False, encoding='cp949')

# %%
df_postagged.shape
# Out:
# (54115, 4)

# %% [markdown]
# # 3. 명사만 추출

# %%
import pandas as pd
df_postagged = pd.read_csv('data/naver_pos.csv', encoding='cp949')

df_postagged.head(1)
# Out:
#    query  no token pos
# 0  전주 여행   1    25  SN

# %%
select_pos = ['NNG','NNP']  # mecab의 명사 pos tag
df_nouns = df_postagged[df_postagged['pos'].isin(select_pos)]
df_nouns.to_csv('data/naver_pos_nouns.csv', index=False, encoding='cp949')

# %% [markdown]
# # 4. 빈도분석
# - token 경주빈도 전주빈도 빈도합

# %%
df_nouns = pd.read_csv('data/naver_pos_nouns.csv', encoding='cp949')
df_nouns.head()
# Out:
#    query  no token  pos
# 0  전주 여행   1     곳  NNG
# 1  전주 여행   1    추천  NNG
# 2  전주 여행   1    부탁  NNG
# 3  전주 여행   1    아이  NNG
# 4  전주 여행   1    시점  NNG

# %%
df_nouns.groupby(['query','token'], as_index=False)['pos'].count()
# Out:
#       query token  pos
# 0     경주 여행    가격    5
# 1     경주 여행    가능   30
# 2     경주 여행  가보세요   10
# 3     경주 여행   가본적    5
# 4     경주 여행    가시    5
# ...     ...   ...  ...
# 996   전주 여행    효율    5
# 997   전주 여행     후    5
# 998   전주 여행    휴가    5
# 999   전주 여행    휴무    5
# 1000  전주 여행    흐노    5
#
# [1001 rows x 3 columns]

# %%
df_token_grp = df_nouns.groupby('query')['token'].value_counts()
df_token_grp = df_token_grp.reset_index(name='token_count')

# %%
df_token_grp.head()
# Out:
#    query token  token_count
# 0  경주 여행    코스          447
# 1  경주 여행    추천          424
# 2  경주 여행    계획          151
# 3  경주 여행     곳          134
# 4  경주 여행    맛집          133

# %%
df_gj = df_token_grp.loc[df_token_grp['query']=='경주 여행', ['token','token_count']]
df_jj = df_token_grp.loc[df_token_grp['query']=='전주 여행', ['token','token_count']]
df_gj.shape, df_jj.shape
# Out:
# ((535, 2), (466, 2))

# %%
df_gj.head()
# Out:
#   token  token_count
# 0    코스          447
# 1    추천          424
# 2    계획          151
# 3     곳          134
# 4    맛집          133

# %%
df_jj.head()
# Out:
#     token  token_count
# 535    코스          459
# 536     곳          433
# 537     봉          330
# 538    맛집          322
# 539    여수          315

# %%
# token 기준으로 merge
# df_gj(경주 명사 출현횟수),  df_jj(전주 명사 출현횟수) 병합
import numpy as np
df_mrg = pd.merge(df_gj, df_jj, on='token', how='outer')
df_mrg.columns = ['token', '경주빈도', '전주빈도']
df_mrg.fillna(0, inplace=True)
df_mrg['경주빈도'] = df_mrg['경주빈도'].astype('int')
df_mrg['전주빈도'] = df_mrg['전주빈도'].astype(np.int32)
df_mrg.head(1)
# Out:
#   token  경주빈도  전주빈도
# 0    코스   447   459

# %%
df_mrg['빈도합'] = df_mrg['경주빈도'] + df_mrg['전주빈도']
df_mrg['경주비율'] = df_mrg['경주빈도'] / df_mrg['빈도합']
df_mrg['전주비율'] = df_mrg['전주빈도'] / df_mrg['빈도합']
df_mrg['경주비율'] = df_mrg['경주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg['전주비율'] = df_mrg['전주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg.to_csv('data/naver_pos_nouns_count.csv', index=False, encoding='cp949')

# %% [markdown]
# # 5. 빈도 시각화(워드 클라우드, Text)
# - 전주여행 워드클라우드/ 경주여행 워드클라우드

# %%
df_nouns = pd.read_csv('data/naver_pos_nouns.csv', encoding='cp949')
df_nouns.loc[::3000]
# Out:
#        query   no token  pos
# 0      전주 여행    1     곳  NNG
# 3000   전주 여행  163    예상  NNG
# 6000   전주 여행  327  대중교통  NNG
# 9000   전주 여행  490    전문  NNG
# 12000  경주 여행  185    가족  NNG
# 15000  경주 여행  377    추천  NNG

# %%
df_gj_noun_list = df_nouns.loc[df_nouns['query'] =='경주 여행', 'token'].to_list()
df_jj_noun_list = df_nouns.loc[df_nouns['query'] =='전주 여행', 'token'].to_list()
gj_text = ' '.join(df_gj_noun_list)
jj_text = ' '.join(df_jj_noun_list)

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt
img = Image.open('data/heart.jpg')
mask = np.array(img)

wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf',
    background_color='white',
    colormap='Blues',
    collocations=True,  # 특정단어가 자주 같이 나오면 같이 뿌려 ex)황리길
    max_words=200,
    scale=2,  # 이미지 크기의 비율(파일 저장시)
    mask=mask,
    contour_color='blue',
    contour_width=1
).generate(gj_text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_경주.jpg')

# %%
img = Image.open('data/korea-house-black-fill.png')
mask = np.array(img)

wordcloud = WordCloud(
    font_path='data/NanumPenScript-Regular.ttf',
    background_color='white',
    colormap='Blues',
    collocations=True,  # 특정단어가 자주 같이 나오면 같이 뿌려 ex)황리길
    max_words=200,
    scale=2,  # 이미지 크기의 비율(파일 저장시)
    mask=mask,
    contour_color='blue',
    contour_width=1
).generate(jj_text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
wordcloud.to_file('data/naver_전주.jpg')

# %% [markdown]
# # 빈도수 시각화(nltk.Text)

# %%
df_gj_noun_list = df_nouns.loc[df_nouns['query'] =='경주 여행', 'token'].to_list()
df_jj_noun_list = df_nouns.loc[df_nouns['query'] =='전주 여행', 'token'].to_list()
df_gj_noun_list

# %%
import nltk
data_text = nltk.Text(df_gj_noun_list)
plt.figure(figsize=(20,5))
plt.rc('font', family='Malgun Gothic')
data_text.plot(20)
plt.show()

# %%
word, counts = zip(*data_text.vocab().most_common(20))
# print(word)
# print(counts)
plt.figure(figsize=(20,5))
plt.plot(word, counts)
plt.xticks(rotation=45)
plt.xlabel('word')
plt.ylabel('count')
plt.title('경주 최빈 단어 빈도')
plt.show()

# %% [markdown]
# # 6. 유사도 분석
# ## Word2Vec

# %%
df = pd.read_csv('data/naver.csv')
df.sample()
# Out:
#      query   no       title  \
# 415  전주 여행  416  남해, 전주 여행
#
#                                                   link  \
# 415  https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                            description  \
# 415  남해 전주 여행 가려는데 여행지와 맛집 추천좀 해주세요 보리암 다랭이굴 독일마을 전...
#
#                                             total_text
# 415  남해, 전주 여행  남해 전주 여행 가려는데 여행지와 맛집 추천좀 해주세요 보리암 ...

# %%
total_text_list = df['total_text'].to_list()
total_text_list[:2]
# Out:
# ['25년10월5,6,7일  전주여행   전주여행 가볼만한 곳 추천부탁드립니다 25년 10월 초 전주여행 아이들과 함께 가기 좋은 시점이에요 추석에는 문 연 곳이 적을 수 있지만 전주 한옥마을이나 전주비빔밥 맛집은 추천해용 차는 밀릴 가능성이 높으니 미리 출발하는 ',
#  'KTX로 떠나는  전주 여행 , 주요 관광지 도보 이동...   전주 여행 계획 중이시군요 전주역에서 한옥마을까지는 사실 도보로는 좀 멀어요 약 3km 정도 되고 40분 정도 걸립니다 그래서 대부분 택시나 버스를 이용하시는데 택시는 10분 정도면 도착하고 요금도 7 8천원 정도로 부담 없어요 ']

# %%
from mecab import MeCab

select_pos = ['NNP','NNG']
불용어 = {'여행'}
analyzer = MeCab()
total_noun_list = []
for total_text in total_text_list:
    noun_list = [token for token, tag in analyzer.pos(total_text)
                    if tag in select_pos and
                        token not in 불용어 and
                        len(token)>1]
    total_noun_list.append(noun_list)
print(total_noun_list[:2])
# Out:
# [['전주', '전주', '추천', '부탁', '전주', '아이', '시점', '추석', '전주', '한옥마을', '전주비빔밥', '맛집', '추천', '해용', '가능', '출발'], ['전주', '주요', '관광지', '도보', '이동', '전주', '계획', '주역', '한옥마을', '도보', '정도', '정도', '대부분', '택시', '버스', '이용', '택시', '정도', '도착', '요금', '정도', '부담']]

# %%
from gensim.models import Word2Vec
model = Word2Vec(total_noun_list, window=10, min_count=2, workers=-1,
                 sg=1)  # 소량데이터

# %%
model.wv.most_similar('전주')
# Out:
# [('식사', 0.3595535457134247),
#  ('동선', 0.2897421419620514),
#  ('리스트', 0.275379478931427),
#  ('덕진구', 0.2731468081474304),
#  ('현재', 0.2580290138721466),
#  ('가격', 0.2295033037662506),
#  ('반려', 0.22023281455039978),
#  ('답변', 0.21883943676948547),
#  ('한옥마을', 0.21617142856121063),
#  ('허락', 0.2135322391986847)]

# %%
model.wv.most_similar('경주')
# Out:
# [('호수', 0.3641005754470825),
#  ('여름', 0.21867415308952332),
#  ('배차', 0.21632219851016998),
#  ('경기전', 0.2159893959760666),
#  ('인근', 0.21469099819660187),
#  ('황동', 0.2134207934141159),
#  ('다랭이', 0.20914912223815918),
#  ('봉길', 0.20906010270118713),
#  ('남편', 0.2070489227771759),
#  ('체계', 0.20607852935791016)]

# %% [markdown]
# ##  연관분석

# %%
print(total_noun_list[:2])
# Out:
# [['전주', '전주', '추천', '부탁', '전주', '아이', '시점', '추석', '전주', '한옥마을', '전주비빔밥', '맛집', '추천', '해용', '가능', '출발'], ['전주', '주요', '관광지', '도보', '이동', '전주', '계획', '주역', '한옥마을', '도보', '정도', '정도', '대부분', '택시', '버스', '이용', '택시', '정도', '도착', '요금', '정도', '부담']]

# %%
# %%time
from apyori import apriori
rules = apriori(total_noun_list, min_support=0.15, min_confidence=0.3, min_lift=1.01)
rules = list(rules)
len(rules)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 30 ms
# 125

# %%
import pandas as pd
rules_df = pd.DataFrame(None, columns=['lhs', 'rhs', '지지도', '신뢰도', '향상도'])
idx = 0
for row in rules:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        # print(item)
        lhs = item[0]
        lhs = ','.join([x for x in lhs])
        rhs = item[1]
        rhs = ','.join([x for x in rhs])
        confidence = item[2]
        lift = item[3]
        rules_df.loc[idx] = [lhs, rhs, support, confidence,lift]
        idx += 1

#         print("{:10}=>{:16}\t{}\t{}\t{:.2f}".format(lhs, rhs, support, 
#                                                 round(confidence, 2),
#                                                 lift))
rules_df = rules_df.sort_values(by=['신뢰도','향상도'], ascending=False)
rules_df.head(20)
# Out:
#           lhs    rhs    지지도  신뢰도       향상도
# 102     여수,국내     티비  0.150  1.0  6.060606
# 132     주달,국내     티비  0.155  1.0  6.060606
# 138     코스,국내     티비  0.155  1.0  6.060606
# 162     맛집,여수     티비  0.155  1.0  6.060606
# 228     여수,주달     티비  0.155  1.0  6.060606
# 234     여수,코스     티비  0.155  1.0  6.060606
# 307     여수,국내  티비,맛집  0.150  1.0  6.060606
# 312  맛집,국내,여수     티비  0.150  1.0  6.060606
# 377     주달,국내  맛집,티비  0.155  1.0  6.060606
# 382  맛집,주달,국내     티비  0.155  1.0  6.060606
# 391     코스,국내  맛집,티비  0.155  1.0  6.060606
# 396  맛집,코스,국내     티비  0.155  1.0  6.060606
# 431     여수,국내  전주,티비  0.150  1.0  6.060606
# 437  전주,여수,국내     티비  0.150  1.0  6.060606
# 458     여수,국내  티비,주달  0.150  1.0  6.060606
# 464  여수,주달,국내     티비  0.150  1.0  6.060606
# 471     여수,국내  티비,코스  0.150  1.0  6.060606
# 477  여수,코스,국내     티비  0.150  1.0  6.060606
# 500     주달,국내  전주,티비  0.155  1.0  6.060606
# 505  전주,주달,국내     티비  0.155  1.0  6.060606
