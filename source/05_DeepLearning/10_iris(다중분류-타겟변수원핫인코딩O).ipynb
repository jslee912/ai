# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:14pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
div.output {font-size:14pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:14pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:14pt;padding:5px;}
table.dataframe{font-size:14px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:14pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
# div.output {font-size:14pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:14pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:14pt;padding:5px;}
# table.dataframe{font-size:14px;}
# </style>

# %%
import os # 모델 저장할 폴더가 있는지 여부와 폴더 생성
import numpy as np
import pandas as pd # get_dummies(원핫인코딩), crosstab
import seaborn as sns # iris 데이터(데이터프레임) 가져오기
from sklearn import datasets # iris 데이터(X, y) 가져오기
from sklearn.preprocessing import LabelEncoder # 라벨인코더
from tensorflow.keras.utils import to_categorical # 원핫인코딩 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout, LeakyReLU
from tensorflow.keras import metrics # compile
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# %% [markdown]
# - 데이터 셋 생성(seaborn) & 전처리
#     X, y(setosa,versicolor,virginica라벨인코딩-원핫코딩)분리 -> train과 test셋 분리(8:2)
# - 모델 구성(입력4 -> 출력3, layer5: 4->64->128->50->30->3)
# - 모델 학습과정 설정
# - 모델 학습(Earlystopping, ModelCheckpoint추가)
# - 모델평가(시각화, 현재모델과 저장된 최고의 모델 평가, 교차표==혼동행렬)
# - 모델예측/저장

# %% [markdown]
# # 1. 데이터 셋 생성(seaborn) & 전처리

# %%
iris = sns.load_dataset('iris')
iris.loc[::50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 100           6.3          3.3           6.0          2.5   virginica

# %%
# 문자변수 원핫인코딩 방법1
encoder = LabelEncoder()
iris['y'] = encoder.fit_transform(iris['species'])
display(iris.loc[::50])
# utils.to_categorical(iris['species'])[:5]
# to_categorical을 하려면 숫자필드로 라벨인코딩먼저
to_categorical(iris['y'])[::50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  y
# 0             5.1          3.5           1.4          0.2      setosa  0
# 50            7.0          3.2           4.7          1.4  versicolor  1
# 100           6.3          3.3           6.0          2.5   virginica  2
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
# 문자변수 원핫인코딩 방법2
pd.get_dummies(iris.species)[::50]
# Out:
#      setosa  versicolor  virginica
# 0         1           0          0
# 50        0           1          0
# 100       0           0          1

# %%
# 1. 데이터 생성 및 전처리
iris = sns.load_dataset('iris')
# 독립변수와 종속변수 분리
iris_X = iris.iloc[:, :-1].to_numpy()
iris_y = iris.iloc[:, -1]
iris_Y = pd.get_dummies(iris_y).values
# 훈련셋 : 테스트셋 = 8 : 2
X_train, X_test, Y_train, Y_test = train_test_split(iris_X, iris_Y,
                                                   test_size=0.2,
                                                   stratify=iris_Y, # 층화추출
                                                   random_state=4) 
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((120, 4), (120, 3), (30, 4), (30, 3))

# %%
# 층화 추출했는지 확인 
pd.Series(np.argmax(Y_train, axis=1)).value_counts()
# Out:
# 0    40
# 1    40
# 2    40
# dtype: int64

# %%
pd.Series(np.argmax(Y_test, axis=1)).value_counts()
# Out:
# 1    10
# 2    10
# 0    10
# dtype: int64

# %% [markdown]
# # 2. 모델 구성
# (입력4 -> 출력3, layer5: 4->64->128->50->30->3)

# %%
model = Sequential()
model.add(Dense(units=64, input_dim=4, activation='relu'))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=30, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                320
#
#  dense_6 (Dense)             (None, 128)               8320
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 50)                6450
#
#  dropout_4 (Dropout)         (None, 50)                0
#
#  dense_8 (Dense)             (None, 30)                1530
#
#  dropout_5 (Dropout)         (None, 30)                0
#
#  dense_9 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 16,713
# Trainable params: 16,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. 모델 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# # 4. 모델 학습
# (Earlystopping, ModelCheckpoint추가)

# %%
model_save_folder = './model/'
import os
if not os.path.exists(model_save_folder): # 폴더 없으면 폴더 생성
    os.mkdir(model_save_folder)
file = model_save_folder \
        + 'iris-{epoch:03d}-loss{val_loss:.4f}-acc{val_accuracy:.4f}.h5'
# 콜백객체
checkpoint = ModelCheckpoint(
                    filepath=file,
                    monitor='val_accuracy', # 모니터링 지표:loss, val_loss, accuracy
                    save_best_only=True,    # 모니터링 지표가 개선된 경우만 저장
                    mode = 'max',
                    verbose=1) # 로그 출력 여부
earlystopping = EarlyStopping(patience=40)# monitor='val_loss' 기본값
hist=model.fit(X_train,Y_train,batch_size=40,
               epochs=200,
               validation_split=0.2,
               callbacks=[checkpoint,earlystopping])
# Out:
# Epoch 1/200
# 1/3 [=========>....................] - ETA: 1s - loss: 1.1744 - accuracy: 0.3250
# Epoch 1: val_accuracy improved from -inf to 0.25000, saving model to ./model\iris-001-loss1.1591-acc0.2500.h5
# 3/3 [==============================] - 1s 154ms/step - loss: 1.1935 - accuracy: 0.2917 - val_loss: 1.1591 - val_accuracy: 0.2500
# Epoch 2/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1284 - accuracy: 0.3250
# Epoch 2: val_accuracy did not improve from 0.25000
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1099 - accuracy: 0.3542 - val_loss: 1.1387 - val_accuracy: 0.2500
# Epoch 3/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0846 - accuracy: 0.3500
# Epoch 3: val_accuracy did not improve from 0.25000
# 3/3 [==============================] - 0s 21ms/step - loss: 1.1074 - accuracy: 0.3125 - val_loss: 1.1095 - val_accuracy: 0.2500
# Epoch 4/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0901 - accuracy: 0.3500
# Epoch 4: val_accuracy did not improve from 0.25000
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0870 - accuracy: 0.3333 - val_loss: 1.0655 - val_accuracy: 0.2500
# Epoch 5/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9987 - accuracy: 0.5250
# Epoch 5: val_accuracy did not improve from 0.25000
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0176 - accuracy: 0.4271 - val_loss: 1.0006 - val_accuracy: 0.2500
# Epoch 6/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9358 - accuracy: 0.5500
# Epoch 6: val_accuracy improved from 0.25000 to 0.58333, saving model to ./model\iris-006-loss0.9228-acc0.5833.h5
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9778 - accuracy: 0.4583 - val_loss: 0.9228 - val_accuracy: 0.5833
# Epoch 7/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0109 - accuracy: 0.3750
# Epoch 7: val_accuracy improved from 0.58333 to 0.91667, saving model to ./model\iris-007-loss0.8557-acc0.9167.h5
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9730 - accuracy: 0.4583 - val_loss: 0.8557 - val_accuracy: 0.9167
# Epoch 8/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9490 - accuracy: 0.4500
# Epoch 8: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9090 - accuracy: 0.5521 - val_loss: 0.8063 - val_accuracy: 0.7500
# Epoch 9/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8895 - accuracy: 0.6250
# Epoch 9: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8581 - accuracy: 0.6667 - val_loss: 0.7576 - val_accuracy: 0.7500
# Epoch 10/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8402 - accuracy: 0.6500
# Epoch 10: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8093 - accuracy: 0.6458 - val_loss: 0.6995 - val_accuracy: 0.7500
# Epoch 11/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8044 - accuracy: 0.6500
# Epoch 11: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7754 - accuracy: 0.6146 - val_loss: 0.6426 - val_accuracy: 0.9167
# Epoch 12/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7552 - accuracy: 0.6750
# Epoch 12: val_accuracy improved from 0.91667 to 0.95833, saving model to ./model\iris-012-loss0.5965-acc0.9583.h5
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7217 - accuracy: 0.6979 - val_loss: 0.5965 - val_accuracy: 0.9583
# Epoch 13/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6989 - accuracy: 0.7250
# Epoch 13: val_accuracy did not improve from 0.95833
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6420 - accuracy: 0.7917 - val_loss: 0.5401 - val_accuracy: 0.9583
# Epoch 14/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5947 - accuracy: 0.8000
# Epoch 14: val_accuracy did not improve from 0.95833
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6241 - accuracy: 0.7396 - val_loss: 0.4931 - val_accuracy: 0.9583
# Epoch 15/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6543 - accuracy: 0.7250
# Epoch 15: val_accuracy did not improve from 0.95833
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6275 - accuracy: 0.7083 - val_loss: 0.4678 - val_accuracy: 0.9583
# Epoch 16/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6165 - accuracy: 0.6500
# Epoch 16: val_accuracy did not improve from 0.95833
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5826 - accuracy: 0.7292 - val_loss: 0.4307 - val_accuracy: 0.9583
# Epoch 17/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5970 - accuracy: 0.7000
# Epoch 17: val_accuracy improved from 0.95833 to 1.00000, saving model to ./model\iris-017-loss0.3850-acc1.0000.h5
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5186 - accuracy: 0.7396 - val_loss: 0.3850 - val_accuracy: 1.0000
# Epoch 18/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4430 - accuracy: 0.8500
# Epoch 18: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4651 - accuracy: 0.8438 - val_loss: 0.3394 - val_accuracy: 1.0000
# Epoch 19/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5046 - accuracy: 0.6750
# Epoch 19: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4614 - accuracy: 0.7292 - val_loss: 0.3034 - val_accuracy: 1.0000
# Epoch 20/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4818 - accuracy: 0.7000
# Epoch 20: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4579 - accuracy: 0.7917 - val_loss: 0.2803 - val_accuracy: 1.0000
# Epoch 21/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4700 - accuracy: 0.8250
# Epoch 21: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4129 - accuracy: 0.8021 - val_loss: 0.2938 - val_accuracy: 0.9583
# Epoch 22/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4164 - accuracy: 0.8000
# Epoch 22: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4532 - accuracy: 0.7708 - val_loss: 0.2515 - val_accuracy: 1.0000
# Epoch 23/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4209 - accuracy: 0.7500
# Epoch 23: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4019 - accuracy: 0.8125 - val_loss: 0.2258 - val_accuracy: 1.0000
# Epoch 24/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3926 - accuracy: 0.8500
# Epoch 24: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3788 - accuracy: 0.8438 - val_loss: 0.2084 - val_accuracy: 1.0000
# Epoch 25/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4459 - accuracy: 0.8000
# Epoch 25: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3818 - accuracy: 0.8333 - val_loss: 0.2224 - val_accuracy: 0.9583
# Epoch 26/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4186 - accuracy: 0.8250
# Epoch 26: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3837 - accuracy: 0.8229 - val_loss: 0.2450 - val_accuracy: 0.9583
# Epoch 27/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3000 - accuracy: 0.8250
# Epoch 27: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3404 - accuracy: 0.8229 - val_loss: 0.1724 - val_accuracy: 1.0000
# Epoch 28/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3563 - accuracy: 0.8250
# Epoch 28: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3342 - accuracy: 0.8333 - val_loss: 0.1605 - val_accuracy: 1.0000
# Epoch 29/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3161 - accuracy: 0.9000
# Epoch 29: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2715 - accuracy: 0.9167 - val_loss: 0.1645 - val_accuracy: 1.0000
# Epoch 30/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1997 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2440 - accuracy: 0.9479 - val_loss: 0.1827 - val_accuracy: 0.9583
# Epoch 31/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3633 - accuracy: 0.8750
# Epoch 31: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2779 - accuracy: 0.9062 - val_loss: 0.1748 - val_accuracy: 0.9583
# Epoch 32/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2464 - accuracy: 0.9500
# Epoch 32: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3018 - accuracy: 0.8854 - val_loss: 0.1109 - val_accuracy: 1.0000
# Epoch 33/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3594 - accuracy: 0.8750
# Epoch 33: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2824 - accuracy: 0.8958 - val_loss: 0.1009 - val_accuracy: 1.0000
# Epoch 34/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2419 - accuracy: 0.9250
# Epoch 34: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2825 - accuracy: 0.9062 - val_loss: 0.1059 - val_accuracy: 1.0000
# Epoch 35/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2560 - accuracy: 0.9250
# Epoch 35: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2252 - accuracy: 0.9271 - val_loss: 0.1546 - val_accuracy: 0.9583
# Epoch 36/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1667 - accuracy: 0.9750
# Epoch 36: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2318 - accuracy: 0.9167 - val_loss: 0.1021 - val_accuracy: 1.0000
# Epoch 37/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2910 - accuracy: 0.9000
# Epoch 37: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2907 - accuracy: 0.8750 - val_loss: 0.0789 - val_accuracy: 1.0000
# Epoch 38/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1894 - accuracy: 0.9500
# Epoch 38: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2289 - accuracy: 0.9062 - val_loss: 0.0896 - val_accuracy: 1.0000
# Epoch 39/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2352 - accuracy: 0.8500
# Epoch 39: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2527 - accuracy: 0.8646 - val_loss: 0.1424 - val_accuracy: 0.9583
# Epoch 40/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2086 - accuracy: 0.9250
# Epoch 40: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1915 - accuracy: 0.9375 - val_loss: 0.0848 - val_accuracy: 1.0000
# Epoch 41/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2000 - accuracy: 0.9500
# Epoch 41: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1758 - accuracy: 0.9375 - val_loss: 0.0594 - val_accuracy: 1.0000
# Epoch 42/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2799 - accuracy: 0.8750
# Epoch 42: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2496 - accuracy: 0.9062 - val_loss: 0.0573 - val_accuracy: 1.0000
# Epoch 43/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0551 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1416 - accuracy: 0.9583 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 44/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1310 - accuracy: 0.9500
# Epoch 44: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1968 - accuracy: 0.9062 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 45/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1880 - accuracy: 0.9500
# Epoch 45: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1505 - accuracy: 0.9583 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 46/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1976 - accuracy: 0.9500
# Epoch 46: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1760 - accuracy: 0.9375 - val_loss: 0.0441 - val_accuracy: 1.0000
# Epoch 47/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1254 - accuracy: 0.9750
# Epoch 47: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1239 - accuracy: 0.9792 - val_loss: 0.1067 - val_accuracy: 0.9583
# Epoch 48/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1485 - accuracy: 0.9500
# Epoch 48: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1923 - accuracy: 0.9271 - val_loss: 0.0697 - val_accuracy: 0.9583
# Epoch 49/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1510 - accuracy: 0.9250
# Epoch 49: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1690 - accuracy: 0.9271 - val_loss: 0.0376 - val_accuracy: 1.0000
# Epoch 50/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1464 - accuracy: 0.9500
# Epoch 50: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2035 - accuracy: 0.9167 - val_loss: 0.0340 - val_accuracy: 1.0000
# Epoch 51/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1049 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1408 - accuracy: 0.9479 - val_loss: 0.0716 - val_accuracy: 0.9583
# Epoch 52/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1984 - accuracy: 0.9250
# Epoch 52: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1515 - accuracy: 0.9375 - val_loss: 0.0698 - val_accuracy: 0.9583
# Epoch 53/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2274 - accuracy: 0.9000
# Epoch 53: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1620 - accuracy: 0.9375 - val_loss: 0.0344 - val_accuracy: 1.0000
# Epoch 54/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2270 - accuracy: 0.9250
# Epoch 54: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2014 - accuracy: 0.9062 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 55/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1472 - accuracy: 0.9500
# Epoch 55: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1911 - accuracy: 0.9167 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 56/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1904 - accuracy: 0.9250
# Epoch 56: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1268 - accuracy: 0.9688 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 57/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0411 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1157 - accuracy: 0.9583 - val_loss: 0.0635 - val_accuracy: 0.9583
# Epoch 58/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0866 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1120 - accuracy: 0.9688 - val_loss: 0.0342 - val_accuracy: 1.0000
# Epoch 59/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0855 - accuracy: 0.9750
# Epoch 59: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1135 - accuracy: 0.9688 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 60/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1433 - accuracy: 0.9500
# Epoch 60: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1074 - accuracy: 0.9688 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 61/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1734 - accuracy: 0.9250
# Epoch 61: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1178 - accuracy: 0.9583 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 62/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0683 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1224 - accuracy: 0.9688 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 63/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0791 - accuracy: 0.9750
# Epoch 63: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1251 - accuracy: 0.9688 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 64/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2088 - accuracy: 0.9000
# Epoch 64: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1574 - accuracy: 0.9167 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 65/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0903 - accuracy: 0.9750
# Epoch 65: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1421 - accuracy: 0.9479 - val_loss: 0.0408 - val_accuracy: 1.0000
# Epoch 66/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1065 - accuracy: 0.9750
# Epoch 66: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1104 - accuracy: 0.9583 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 67/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0453 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1231 - accuracy: 0.9583 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 68/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0936 - accuracy: 0.9750
# Epoch 68: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1581 - accuracy: 0.9479 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 69/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0834 - accuracy: 0.9750
# Epoch 69: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0997 - accuracy: 0.9688 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 70/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1914 - accuracy: 0.9250
# Epoch 70: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1357 - accuracy: 0.9583 - val_loss: 0.0400 - val_accuracy: 1.0000
# Epoch 71/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0866 - accuracy: 0.9750
# Epoch 71: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1010 - accuracy: 0.9688 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 72/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0545 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1170 - accuracy: 0.9583 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 73/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0816 - accuracy: 0.9500
# Epoch 73: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0958 - accuracy: 0.9583 - val_loss: 0.0365 - val_accuracy: 1.0000
# Epoch 74/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0899 - accuracy: 0.9500
# Epoch 74: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0941 - accuracy: 0.9583 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 75/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1067 - accuracy: 0.9250
# Epoch 75: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1328 - accuracy: 0.9479 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 76/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1307 - accuracy: 0.9500
# Epoch 76: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1309 - accuracy: 0.9375 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 77/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1226 - accuracy: 0.9500
# Epoch 77: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0937 - accuracy: 0.9688 - val_loss: 0.0316 - val_accuracy: 1.0000
# Epoch 78/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0824 - accuracy: 0.9750
# Epoch 78: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0759 - accuracy: 0.9896 - val_loss: 0.0356 - val_accuracy: 1.0000
# Epoch 79/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0587 - accuracy: 0.9750
# Epoch 79: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1241 - accuracy: 0.9479 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 80/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2224 - accuracy: 0.9250
# Epoch 80: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1315 - accuracy: 0.9479 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 81/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1150 - accuracy: 0.9500
# Epoch 81: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1310 - accuracy: 0.9583 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 82/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1381 - accuracy: 0.9250
# Epoch 82: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1144 - accuracy: 0.9479 - val_loss: 0.0426 - val_accuracy: 0.9583
# Epoch 83/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1200 - accuracy: 0.9500
# Epoch 83: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1011 - accuracy: 0.9688 - val_loss: 0.0663 - val_accuracy: 0.9583
# Epoch 84/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2159 - accuracy: 0.9250
# Epoch 84: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1398 - accuracy: 0.9479 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 85/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1645 - accuracy: 0.9500
# Epoch 85: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0948 - accuracy: 0.9792 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 86/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1300 - accuracy: 0.9750
# Epoch 86: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0809 - accuracy: 0.9896 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 87/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1910 - accuracy: 0.9750
# Epoch 87: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1264 - accuracy: 0.9583 - val_loss: 0.0361 - val_accuracy: 1.0000
# Epoch 88/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1132 - accuracy: 0.9500
# Epoch 88: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1381 - accuracy: 0.9583 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 89/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1532 - accuracy: 0.8750
# Epoch 89: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1226 - accuracy: 0.9375 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 90/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0746 - accuracy: 0.9500
# Epoch 90: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0855 - accuracy: 0.9688 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 91/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1879 - accuracy: 0.9750
# Epoch 91: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1325 - accuracy: 0.9688 - val_loss: 0.0356 - val_accuracy: 1.0000
# Epoch 92/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0399 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1011 - accuracy: 0.9688 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 93/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0622 - accuracy: 0.9750
# Epoch 93: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0847 - accuracy: 0.9792 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 94/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0174 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0696 - accuracy: 0.9688 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 95/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1234 - accuracy: 0.9500
# Epoch 95: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0929 - accuracy: 0.9688 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 96/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1371 - accuracy: 0.9500
# Epoch 96: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1326 - accuracy: 0.9271 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 97/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1087 - accuracy: 0.9500
# Epoch 97: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0914 - accuracy: 0.9688 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 98/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1075 - accuracy: 0.9500
# Epoch 98: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0964 - accuracy: 0.9479 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 99/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1041 - accuracy: 0.9500
# Epoch 99: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1170 - accuracy: 0.9688 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 100/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1254 - accuracy: 0.9750
# Epoch 100: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0827 - accuracy: 0.9792 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 101/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1238 - accuracy: 0.9500
# Epoch 101: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1083 - accuracy: 0.9583 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 102/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0753 - accuracy: 1.0000
# Epoch 102: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1123 - accuracy: 0.9583 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 103/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0771 - accuracy: 0.9750
# Epoch 103: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0811 - accuracy: 0.9792 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 104/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1044 - accuracy: 0.9750
# Epoch 104: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1055 - accuracy: 0.9583 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 105/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0197 - accuracy: 1.0000
# Epoch 105: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0870 - accuracy: 0.9792 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 106/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0376 - accuracy: 0.9750
# Epoch 106: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0876 - accuracy: 0.9583 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 107/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1256 - accuracy: 0.9750
# Epoch 107: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0839 - accuracy: 0.9792 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 108/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0221 - accuracy: 1.0000
# Epoch 108: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1097 - accuracy: 0.9688 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 109/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0782 - accuracy: 0.9750
# Epoch 109: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0659 - accuracy: 0.9792 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 110/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0196 - accuracy: 1.0000
# Epoch 110: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0670 - accuracy: 0.9792 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 111/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0760 - accuracy: 0.9500
# Epoch 111: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0811 - accuracy: 0.9688 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 112/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0698 - accuracy: 0.9750
# Epoch 112: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1008 - accuracy: 0.9688 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 113/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0721 - accuracy: 0.9750
# Epoch 113: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0816 - accuracy: 0.9792 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 114/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1294 - accuracy: 0.9500
# Epoch 114: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0984 - accuracy: 0.9583 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 115/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0882 - accuracy: 0.9500
# Epoch 115: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0672 - accuracy: 0.9688 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 116/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0621 - accuracy: 1.0000
# Epoch 116: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1258 - accuracy: 0.9688 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 117/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0559 - accuracy: 1.0000
# Epoch 117: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0934 - accuracy: 0.9896 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 118/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0670 - accuracy: 1.0000
# Epoch 118: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0849 - accuracy: 0.9792 - val_loss: 0.0505 - val_accuracy: 0.9583
# Epoch 119/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1310 - accuracy: 0.9500
# Epoch 119: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1089 - accuracy: 0.9375 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 120/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0627 - accuracy: 0.9750
# Epoch 120: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1113 - accuracy: 0.9583 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 121/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0803 - accuracy: 0.9750
# Epoch 121: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1460 - accuracy: 0.9479 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 122/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1178 - accuracy: 0.9750
# Epoch 122: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0816 - accuracy: 0.9896 - val_loss: 0.0477 - val_accuracy: 0.9583
# Epoch 123/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1614 - accuracy: 0.9000
# Epoch 123: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1111 - accuracy: 0.9479 - val_loss: 0.0495 - val_accuracy: 0.9583
# Epoch 124/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0932 - accuracy: 0.9750
# Epoch 124: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1006 - accuracy: 0.9375 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 125/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0517 - accuracy: 0.9750
# Epoch 125: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0755 - accuracy: 0.9688 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 126/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0717 - accuracy: 0.9750
# Epoch 126: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0686 - accuracy: 0.9792 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 127/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0316 - accuracy: 1.0000
# Epoch 127: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0825 - accuracy: 0.9792 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 128/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0461 - accuracy: 1.0000
# Epoch 128: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0999 - accuracy: 0.9896 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 129/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0618 - accuracy: 0.9750
# Epoch 129: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1122 - accuracy: 0.9792 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 130/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1269 - accuracy: 0.9750
# Epoch 130: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0683 - accuracy: 0.9896 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 131/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0312 - accuracy: 1.0000
# Epoch 131: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0687 - accuracy: 0.9896 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 132/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0919 - accuracy: 0.9750
# Epoch 132: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0967 - accuracy: 0.9688 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 133/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0642 - accuracy: 1.0000
# Epoch 133: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0733 - accuracy: 0.9792 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 134/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0435 - accuracy: 0.9750
# Epoch 134: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0636 - accuracy: 0.9792 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 135/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1507 - accuracy: 0.9500
# Epoch 135: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0721 - accuracy: 0.9792 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 136/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1077 - accuracy: 0.9500
# Epoch 136: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1072 - accuracy: 0.9583 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 137/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0387 - accuracy: 1.0000
# Epoch 137: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1042 - accuracy: 0.9792 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 138/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1218 - accuracy: 0.9750
# Epoch 138: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0771 - accuracy: 0.9792 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 139/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1477 - accuracy: 0.9750
# Epoch 139: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0871 - accuracy: 0.9792 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 140/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0307 - accuracy: 1.0000
# Epoch 140: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0759 - accuracy: 0.9688 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 141/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0685 - accuracy: 0.9750
# Epoch 141: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0541 - accuracy: 0.9792 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 142/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0632 - accuracy: 0.9750
# Epoch 142: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0663 - accuracy: 0.9792 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 143/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0577 - accuracy: 0.9750
# Epoch 143: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0726 - accuracy: 0.9688 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 144/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0224 - accuracy: 1.0000
# Epoch 144: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0670 - accuracy: 0.9896 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 145/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1518 - accuracy: 0.9500
# Epoch 145: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0875 - accuracy: 0.9688 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 146/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1178 - accuracy: 0.9750
# Epoch 146: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0653 - accuracy: 0.9896 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 147/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1429 - accuracy: 0.9750
# Epoch 147: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0854 - accuracy: 0.9792 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 148/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1039 - accuracy: 0.9500
# Epoch 148: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0655 - accuracy: 0.9688 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 149/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1881 - accuracy: 0.9750
# Epoch 149: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1001 - accuracy: 0.9792 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 150/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1686 - accuracy: 0.9750
# Epoch 150: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1077 - accuracy: 0.9688 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 151/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0394 - accuracy: 1.0000
# Epoch 151: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0834 - accuracy: 0.9792 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 152/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0924 - accuracy: 0.9750
# Epoch 152: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0857 - accuracy: 0.9688 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 153/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0191 - accuracy: 1.0000
# Epoch 153: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1096 - accuracy: 0.9479 - val_loss: 0.0434 - val_accuracy: 0.9583
# Epoch 154/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0716 - accuracy: 0.9750
# Epoch 154: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0926 - accuracy: 0.9792 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 155/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0436 - accuracy: 1.0000
# Epoch 155: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0965 - accuracy: 0.9688 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 156/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 156: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0634 - accuracy: 0.9792 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 157/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1328 - accuracy: 0.9750
# Epoch 157: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0893 - accuracy: 0.9792 - val_loss: 0.0295 - val_accuracy: 1.0000
# Epoch 158/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0269 - accuracy: 1.0000
# Epoch 158: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0597 - accuracy: 0.9688 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 159/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0642 - accuracy: 0.9750
# Epoch 159: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0706 - accuracy: 0.9792 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 160/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0924 - accuracy: 0.9750
# Epoch 160: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0840 - accuracy: 0.9792 - val_loss: 0.0152 - val_accuracy: 1.0000

# %% [markdown]
# # 5. 모델 평가
# (시각화, 현재모델과 저장된 최고의 모델 평가, 교차표==혼동행렬)

# %%
# 학습과정 표시하기
import matplotlib.pyplot as plt
fig, loss_ax = plt.subplots(figsize=(10,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax 생성
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(bbox_to_anchor=(0.955, 0.7))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 모델 평가
loss_and_acc =model.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc[0]:.4f}, accuracy:{loss_and_acc[1]:.4f}')
# Out:
# loss:0.1647, accuracy:0.9333

# %%
model1 = load_model('model/iris-007-loss0.7205-acc1.0000.h5')
loss_and_acc1 =model1.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc1[0]:.4f}, accuracy:{loss_and_acc1[1]:.4f}')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 model1 = load_model('model/iris-007-loss0.7205-acc1.0000.h5')
#       2 loss_and_acc1 =model1.evaluate(X_test, Y_test, verbose=0)
#       3 print(f'loss:{loss_and_acc1[0]:.4f}, accuracy:{loss_and_acc1[1]:.4f}')
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\keras\saving\save.py:226, in load_model(filepath, custom_objects, compile, options)
#     224 if isinstance(filepath_str, str):
#     225     if not tf.io.gfile.exists(filepath_str):
# --> 226         raise IOError(
#     227             f"No file or directory found at {filepath_str}"
#     228         )
#     230     if tf.io.gfile.isdir(filepath_str):
#     231         return saved_model_load.load(
#     232             filepath_str, compile, options
#     233         )
#
# OSError: No file or directory found at model/iris-007-loss0.7205-acc1.0000.h5

# %%
model2 = load_model('model/iris-005-loss0.7852-acc1.0000.h5')
loss_and_acc2 =model2.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc2[0]:.4f}, accuracy:{loss_and_acc2[1]:.4f}')
