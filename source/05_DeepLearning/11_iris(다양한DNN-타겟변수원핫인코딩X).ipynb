# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:14pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
div.output {font-size:14pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:14pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:14pt;padding:5px;}
table.dataframe{font-size:14px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:14pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
# div.output {font-size:14pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:14pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:14pt;padding:5px;}
# table.dataframe{font-size:14px;}
# </style>

# %%
import os # 모델 저장할 폴더가 있는지 여부와 폴더 생성
import numpy as np
import pandas as pd # get_dummies(원핫인코딩), crosstab
import seaborn as sns # iris 데이터(데이터프레임) 가져오기
from sklearn import datasets # iris 데이터(X, y) 가져오기
from sklearn.preprocessing import LabelEncoder # 라벨인코더
from tensorflow.keras.utils import to_categorical # 원핫인코딩 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout, LeakyReLU
from tensorflow.keras import metrics # compile
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 기본적인 DNN

# %%
# 1. 데이터 생성 및 전처리
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.2,
                                                   stratify=iris_y)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((120, 4), (120,), (30, 4), (30,))

# %%
# 2. 모델구성
model = Sequential([
    Input(4),
    Dense(units=64, activation='relu'),
    Dense(units=128, activation='relu'),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 64)                320
#
#  dense_21 (Dense)            (None, 128)               8320
#
#  dense_22 (Dense)            (None, 50)                6450
#
#  dense_23 (Dense)            (None, 30)                1530
#
#  dense_24 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 16,713
# Trainable params: 16,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 3. 학습과정 설정
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
# 4. 모델 학습
earlystopping = EarlyStopping(patience=40)# monitor='val_loss' 기본값
hist = model.fit(train_X,train_y,
               epochs=200,
               validation_split=0.1,
               callbacks=[earlystopping])
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 88ms/step - loss: 0.0879 - accuracy: 0.9630 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 2/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0627 - accuracy: 0.9630 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 3/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0929 - accuracy: 0.9630 - val_loss: 0.0409 - val_accuracy: 1.0000
# Epoch 4/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0609 - accuracy: 0.9815 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 5/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0590 - accuracy: 0.9815 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 6/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0534 - accuracy: 0.9815 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 7/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0537 - accuracy: 0.9815 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 8/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0541 - accuracy: 0.9815 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 9/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0531 - accuracy: 0.9815 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 10/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0580 - accuracy: 0.9815 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 11/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0684 - accuracy: 0.9815 - val_loss: 0.0434 - val_accuracy: 1.0000
# Epoch 12/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0605 - accuracy: 0.9815 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 13/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0540 - accuracy: 0.9815 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 14/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0824 - accuracy: 0.9722 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 15/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0533 - accuracy: 0.9815 - val_loss: 0.0497 - val_accuracy: 1.0000
# Epoch 16/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0658 - accuracy: 0.9815 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 17/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0699 - accuracy: 0.9722 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 18/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0652 - accuracy: 0.9815 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 19/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0539 - accuracy: 0.9815 - val_loss: 0.0534 - val_accuracy: 1.0000
# Epoch 20/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0603 - accuracy: 0.9815 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 21/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0663 - accuracy: 0.9722 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 22/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0795 - accuracy: 0.9722 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 23/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0736 - accuracy: 0.9722 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 24/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0696 - accuracy: 0.9815 - val_loss: 0.0449 - val_accuracy: 1.0000
# Epoch 25/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0832 - accuracy: 0.9630 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 26/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0464 - accuracy: 0.9722 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 27/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0836 - accuracy: 0.9722 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 28/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0508 - accuracy: 0.9815 - val_loss: 0.0427 - val_accuracy: 1.0000
# Epoch 29/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0665 - accuracy: 0.9815 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 30/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0553 - accuracy: 0.9815 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 31/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0774 - accuracy: 0.9722 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 32/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0523 - accuracy: 0.9815 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 33/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0521 - accuracy: 0.9815 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 34/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0519 - accuracy: 0.9815 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 35/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0543 - accuracy: 0.9815 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 36/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0599 - accuracy: 0.9815 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 37/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0879 - accuracy: 0.9630 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 38/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0399 - accuracy: 0.9815 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 39/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0805 - accuracy: 0.9630 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 40/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0439 - accuracy: 0.9815 - val_loss: 0.0882 - val_accuracy: 0.9167
# Epoch 41/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0942 - accuracy: 0.9537 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 42/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1279 - accuracy: 0.9537 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 43/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0871 - accuracy: 0.9722 - val_loss: 0.1265 - val_accuracy: 0.9167
# Epoch 44/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0963 - accuracy: 0.9722 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 45/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0628 - accuracy: 0.9815 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 46/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0720 - accuracy: 0.9722 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 47/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0499 - accuracy: 0.9815 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 48/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0614 - accuracy: 0.9815 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 49/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0486 - accuracy: 0.9815 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 50/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0687 - accuracy: 0.9815 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 51/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0560 - accuracy: 0.9815 - val_loss: 0.0248 - val_accuracy: 1.0000
# Epoch 52/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0627 - accuracy: 0.9815 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 53/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0604 - accuracy: 0.9815 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 54/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0571 - accuracy: 0.9815 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 55/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0515 - accuracy: 0.9815 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 56/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0512 - accuracy: 0.9815 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 57/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0580 - accuracy: 0.9815 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 58/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 59/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0533 - accuracy: 0.9815 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 60/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0524 - accuracy: 0.9815 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 61/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 62/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0638 - accuracy: 0.9815 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 63/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0507 - accuracy: 0.9815 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 64/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0546 - accuracy: 0.9815 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 65/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0516 - accuracy: 0.9815 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 66/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0511 - accuracy: 0.9815 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 67/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0544 - accuracy: 0.9815 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 68/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0724 - accuracy: 0.9722 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 69/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0659 - accuracy: 0.9907 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 70/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0635 - accuracy: 0.9815 - val_loss: 0.0405 - val_accuracy: 1.0000
# Epoch 71/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0522 - accuracy: 0.9815 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 72/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0594 - accuracy: 0.9815 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 73/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0680 - accuracy: 0.9815 - val_loss: 0.0508 - val_accuracy: 1.0000
# Epoch 74/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0595 - accuracy: 0.9815 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 75/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0597 - accuracy: 0.9722 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 76/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0514 - accuracy: 0.9815 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 77/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0511 - accuracy: 0.9815 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 78/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0593 - accuracy: 0.9815 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 79/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0494 - accuracy: 0.9815 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 80/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0511 - accuracy: 0.9815 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 81/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0526 - accuracy: 0.9815 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 82/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0493 - accuracy: 0.9815 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 83/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0526 - accuracy: 0.9815 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 84/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0495 - accuracy: 0.9815 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 85/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0523 - accuracy: 0.9815 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 86/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0528 - accuracy: 0.9815 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 87/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0508 - accuracy: 0.9815 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 88/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0512 - accuracy: 0.9815 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 89/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0599 - accuracy: 0.9815 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 90/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0605 - accuracy: 0.9722 - val_loss: 0.0093 - val_accuracy: 1.0000

# %% [markdown]
# # 2. sklearn 이용
# - 원핫인코딩를 하지 않고 라벨인코딩까지만 해야 작동

# %%
from sklearn.neural_network import MLPClassifier

# %%
# 1. 데이터
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((120, 4), (120,), (30, 4), (30,))

# %%
# 모델생성, 컴파일, 학습 설정
model = MLPClassifier(
            hidden_layer_sizes=(64,128, 50),  # hidden layer의 units 수
            activation='relu', 
            solver='adam',  # sgd등의 optimizer
            batch_size=40,
            max_iter=1000,  # 학습 최대 횟수
            early_stopping=True,  # 조기 종료 활성화
            n_iter_no_change=20,  # earlyStopping의 patience와 유사
            validation_fraction=0.1,  # 검증셋 비율
            warm_start=False    # - 재학습시 w와b를 새롭게 리셋, True일 경우 이전학습에 이어서 학습(기존 방식에서는 조절X)
)

# %%
# 학습
model.fit(train_X, train_y)
# Out:
# MLPClassifier(batch_size=40, early_stopping=True,
#               hidden_layer_sizes=(64, 128, 50), max_iter=1000,
#               n_iter_no_change=20)

# %%
model.score(test_X, test_y)
# Out:
# 0.9666666666666667

# %%
iris_X[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
# 모델 사용(예측)
input_data = [[5.1, 3.5, 1.4, 0.2]]
model.predict(input_data)
# Out:
# array([0])

# %%
# 교차표
# test_y  # 실제값
hat_y = model.predict(test_X)  # 예측값
pd.crosstab(test_y, hat_y, rownames=['real'], colnames=['predict'])
# Out:
# predict   0   1  2
# real
# 0        10   0  0
# 1         0  10  0
# 2         0   1  9

# %% [markdown]
# # 3. 클래스를 생성하여 모델 생성함수 사용

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4, activation='relu', output_dim=3):  # 모델을 리턴
#         model = Sequential()
#         model.add(Input(input_dim))
#         model.add(Dense(units=50, activation=activation))
#         model.add(Dense(units=30, activation=activation))
#         model.add(Dense(units=3, activation='softmax'))
        # 모델 구성
        model = Sequential([
            Input(input_dim),
            Dense(units=50, activation=activation),
            Dense(units=30, activation=activation),
            Dense(units=output_dim, activation='softmax')
        ])
        # 학습 설정
        model.compile(loss='sparse_categorical_crossentropy',
                     optimizer='adam',
                     metrics=['accuracy'])
        return model

# %%
# 1. 데이터
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# 2. 모델
model = DNNClassifier.build(input_dim=4, activation='elu')
# 3. 모델 학습
hist = model.fit(train_X, train_y, epochs=50, validation_split=0.1, verbose=0)

# %%
# 모델 평가
loss, accuracy = model.evaluate(test_X, test_y)
print(f'정확도 : {accuracy*100}%')
# Out:
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1038 - accuracy: 1.0000
# 정확도 : 100.0%

# %% [markdown]
# # 4. 함수형 API
# - 병렬처리, Residual block

# %%
# 기존 model 스타일 1
model = Sequential()
model.add(Input(shape=(4,)))
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=30, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
# 기존 model 스타일 2
model = Sequential([
    Input(shape=(4,)),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax')
])

# %%
# 기존 model 스타일 3  (함수형 API)
from tensorflow.keras import Model
input_ = Input(shape=(4,))
layer1 = Dense(units=50, activation='relu')(input_)  # 함수형 API 스타일(직렬)
layer2 = Dense(units=30, activation='relu')(layer1)
output = Dense(units=3, activation='softmax')(layer2)
model = Model(inputs= input_, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 4)]               0
#
#  dense_66 (Dense)            (None, 50)                250
#
#  dense_67 (Dense)            (None, 30)                1530
#
#  dense_68 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 병렬 처리 방식
from tensorflow.keras.layers import concatenate
input_ = Input(shape=(4,))
dense1 = Dense(50, activation='relu')(input_)
dense2 = Dense(80, activation='relu')(input_)
dense3 = Dense(30, activation='relu')(input_)
x = concatenate([dense1, dense2, dense3])
output = Dense(units=3, activation='softmax')(x)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 4)]          0           []
#
#  dense_69 (Dense)               (None, 50)           250         ['input_22[0][0]']
#
#  dense_70 (Dense)               (None, 80)           400         ['input_22[0][0]']
#
#  dense_71 (Dense)               (None, 30)           150         ['input_22[0][0]']
#
#  concatenate (Concatenate)      (None, 160)          0           ['dense_69[0][0]',
#                                                                   'dense_70[0][0]',
#                                                                   'dense_71[0][0]']
#
#  dense_72 (Dense)               (None, 3)            483         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 1,283
# Trainable params: 1,283
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 레지듀얼 블럭(Residual Block) : 
    #딥러닝에서 기울기 소실 문제로 학습이 잘 되지 않는 부분을 해결하기 위한 제안
from tensorflow.keras.layers import add
input_ = Input(shape=(4,))
dense1 = Dense(50, activation='relu')(input_)
dense2 = Dense(50, activation='relu')(dense1)
dense3 = add([dense1, dense2])
output = Dense(units=3, activation='softmax')(dense3)
model  = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 4)]          0           []
#
#  dense_73 (Dense)               (None, 50)           250         ['input_23[0][0]']
#
#  dense_74 (Dense)               (None, 50)           2550        ['dense_73[0][0]']
#
#  add (Add)                      (None, 50)           0           ['dense_73[0][0]',
#                                                                   'dense_74[0][0]']
#
#  dense_75 (Dense)               (None, 3)            153         ['add[0][0]']
#
# ==================================================================================================
# Total params: 2,953
# Trainable params: 2,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 학습과정 설정 & 학습
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam', metrics=['accuracy'])
model.fit(train_X, train_y, epochs=200, verbose=0)

# %%
# 학습 평가
loss, accuracy = model.evaluate(test_X, test_y, verbose=0)
print(f'accuracy : {accuracy}')
# Out:
# accuracy : 0.9666666388511658
